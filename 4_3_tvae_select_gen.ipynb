# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 제출 파일 생성 관련
import os
import zipfile

# 데이터 처리 및 분석
import pandas as pd
import numpy as np
from scipy import stats
from tqdm import tqdm

# To ignore all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 불러오기
path = '/content/drive/MyDrive/Colab Notebooks/fsi/open/'
save_path = '/content/drive/MyDrive/Colab Notebooks/fsi/processed_data/1_all_pre_syn.csv'

train_all = pd.read_csv(path + "train.csv")
test_all = pd.read_csv(path + "test.csv")
saved_train = pd.read_csv(save_path)

save_path = '/content/drive/MyDrive/Colab Notebooks/fsi/processed_data'
all_synthetic_data = pd.read_csv(save_path + '/tvae_syn_data.csv')

train = train_all.drop(columns="ID")
saved_train["Fraud_Type"].value_counts()
# Out:
# Fraud_Type
# m    118800
# a       100
# j       100
# h       100
# k       100
# c       100
# g       100
# i       100
# b       100
# f       100
# d       100
# e       100
# l       100
# Name: count, dtype: int64

# %%
# 설치
# !pip install sdmetrics

# %%
# !pip install sdv

# %%
# !pip install catboost

# %% [markdown]
# # Statistical

# %%
from sdv.metadata import SingleTableMetadata

# 메타 데이터 타입 설정
column_sdtypes = {
        'Account_amount_daily_limit': 'numerical',
        'Transaction_num_connection_failure': 'numerical',
        'Number_of_transaction_with_the_account': 'numerical',
        'Transaction_history_with_the_account': 'numerical',
        'Account_initial_balance': 'numerical',
        'Account_balance': 'numerical',
        'Customer_identification_number': 'categorical',
        'Customer_personal_identifier': 'categorical',
        'Account_account_number': 'categorical',
        'IP_Address': 'ipv4_address',
        'Location': 'categorical',
        'Recipient_Account_Number': 'categorical',
        'Fraud_Type': 'categorical',
        'Customer_Birthyear': 'numerical'
    }

fraud_type = 'a'
subset = saved_train[saved_train["Fraud_Type"] == fraud_type]
syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == fraud_type]
subset = subset.drop('Time_difference_seconds', axis=1)

# 메타데이터 생성 및 모델 학습
metadata = SingleTableMetadata()

metadata.detect_from_dataframe(subset)
metadata.set_primary_key(None)

# 각 컬럼에 대해 데이터 타입 설정
for column, sdtype in column_sdtypes.items():
    metadata.update_column(
        column_name=column,
        sdtype=sdtype
    )

# %%
from sdmetrics.reports.single_table import DiagnosticReport
from sdmetrics.reports.single_table import QualityReport

types = saved_train.Fraud_Type.unique()
statis = pd.DataFrame(types, columns=['Fraud_Type'])
statis['Data_Quality'] = 0
statis['Data_Diagnostic'] = 0
statis['Conti_statis'] = 0
statis['Cate_statis'] = 0

for x in types:
    if x == 'm':
        continue
    subset = saved_train[saved_train["Fraud_Type"] == x]
    syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == x]
    subset = subset.drop('Time_difference_seconds', axis=1)

    # 메타데이터 생성 및 모델 학습
    metadata = SingleTableMetadata()
    metadata.detect_from_dataframe(subset)
    metadata.set_primary_key(None)

    # 각 컬럼에 대해 데이터 타입 설정
    for column, sdtype in column_sdtypes.items():
        metadata.update_column(
            column_name=column,
            sdtype=sdtype)

    report_q = QualityReport()
    report_d = DiagnosticReport()

    metadata_as_dict = metadata.to_dict()
    report_q.generate(subset, syn_subset, metadata_as_dict)
    report_d.generate(subset, syn_subset, metadata_as_dict)

    statis.loc[statis['Fraud_Type'] == x, 'Data_Quality'] = report_q.get_score()
    statis.loc[statis['Fraud_Type'] == x, 'Data_Diagnostic'] = report_d.get_score()
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:01<00:00, 43.80it/s]|
# Column Shapes Score: 73.72%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [04:03<00:00,  8.01it/s]|
# Column Pair Trends Score: 57.25%
#
# Overall Score (Average): 65.49%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1173.70it/s]|
# Data Validity Score: 98.33%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 209.14it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.17%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:01<00:00, 41.09it/s]|
# Column Shapes Score: 76.6%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [07:40<00:00,  4.24it/s]|
# Column Pair Trends Score: 63.74%
#
# Overall Score (Average): 70.17%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1242.94it/s]|
# Data Validity Score: 98.56%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 222.52it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.28%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 346.92it/s]|
# Column Shapes Score: 80.48%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:06<00:00, 29.22it/s]|
# Column Pair Trends Score: 65.53%
#
# Overall Score (Average): 73.01%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1176.88it/s]|
# Data Validity Score: 99.99%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 169.19it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:02<00:00, 29.86it/s]|
# Column Shapes Score: 75.23%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [08:07<00:00,  4.01it/s]|
# Column Pair Trends Score: 61.94%
#
# Overall Score (Average): 68.59%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 972.10it/s]|
# Data Validity Score: 98.33%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 172.46it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.17%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 238.14it/s]|
# Column Shapes Score: 74.27%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.23it/s]|
# Column Pair Trends Score: 60.09%
#
# Overall Score (Average): 67.18%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 836.89it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 235.98it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 72.89it/s]|
# Column Shapes Score: 76.36%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [03:20<00:00,  9.74it/s]|
# Column Pair Trends Score: 64.51%
#
# Overall Score (Average): 70.44%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1193.25it/s]|
# Data Validity Score: 98.74%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 248.51it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.37%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:01<00:00, 42.60it/s]|
# Column Shapes Score: 76.96%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [06:56<00:00,  4.69it/s]|
# Column Pair Trends Score: 62.25%
#
# Overall Score (Average): 69.61%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1225.27it/s]|
# Data Validity Score: 98.62%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 265.13it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.31%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 294.04it/s]|
# Column Shapes Score: 76.75%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.24it/s]|
# Column Pair Trends Score: 64.28%
#
# Overall Score (Average): 70.51%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1155.22it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 262.72it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 315.13it/s]|
# Column Shapes Score: 82.06%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:06<00:00, 29.36it/s]|
# Column Pair Trends Score: 66.62%
#
# Overall Score (Average): 74.34%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1201.52it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 233.99it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 284.29it/s]|
# Column Shapes Score: 77.25%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.35it/s]|
# Column Pair Trends Score: 62.76%
#
# Overall Score (Average): 70.0%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1193.66it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 232.50it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 299.72it/s]|
# Column Shapes Score: 78.7%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:08<00:00, 28.50it/s]|
# Column Pair Trends Score: 64.92%
#
# Overall Score (Average): 71.81%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1127.49it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 238.43it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 317.96it/s]|
# Column Shapes Score: 77.13%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:03<00:00, 30.53it/s]|
# Column Pair Trends Score: 63.45%
#
# Overall Score (Average): 70.29%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1209.41it/s]|
# Data Validity Score: 99.98%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 236.23it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.99%

# %%
statis
# Out:
#    Fraud_Type  Data_Quality  Data_Diagnostic  Conti_statis  Cate_statis
# 0           m      0.000000         0.000000             0            0
# 1           a      0.654851         0.991672             0            0
# 2           j      0.701725         0.992794             0            0
# 3           h      0.730080         0.999973             0            0
# 4           k      0.685878         0.991663             0            0
# 5           c      0.671822         1.000000             0            0
# 6           g      0.704361         0.993717             0            0
# 7           i      0.696058         0.993125             0            0
# 8           b      0.705124         0.999999             0            0
# 9           f      0.743384         1.000000             0            0
# 10          d      0.700025         1.000000             0            0
# 11          e      0.718118         1.000000             0            0
# 12          l      0.702907         0.999899             0            0

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sdmetrics.visualization import get_column_plot

# 시간 차이 계산
subset['Time_difference_seconds'] = pd.to_timedelta(subset['Time_difference']).dt.total_seconds()
syn_subset['Time_difference_seconds'] = pd.to_timedelta(syn_subset['Time_difference']).dt.total_seconds()

# 그래프에 추가할 컬럼 목록
columns = ['Transaction_Amount', 'Account_initial_balance', 'Account_balance',
           'Account_one_month_max_amount',
           'Account_one_month_std_dev', 'Account_dawn_one_month_max_amount',
           'Time_difference_seconds', 'Account_dawn_one_month_std_dev']

# 3x3 서브플롯 생성
fig = make_subplots(rows=3, cols=3, subplot_titles=columns)

# 각 컬럼에 대해 그래프 생성 및 서브플롯에 추가
for i, col in enumerate(columns):
    row = i // 3 + 1
    col_idx = i % 3 + 1

    # 각 컬럼에 대한 plotly figure 생성
    fig_ = get_column_plot(
        real_data=subset,
        synthetic_data=syn_subset,
        column_name=col,
        plot_type='distplot'
    )

    # 서브플롯에 그래프 추가
    for trace in fig_.data:
        fig.add_trace(trace, row=row, col=col_idx)

# 레이아웃 조정
fig.update_layout(
    height=900,
    width=1200,  # 가로 길이를 늘림
    title_text= x + ": Comparison of Distributions",
    title_font=dict(size=14)  # 제목 글씨 크기 조정
)

# 인터랙티브한 플롯 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.0.min.js"></script>                <div id="43cab55f-bd85-4587-bca9-5f356f268a40" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43cab55f-bd85-4587-bca9-5f356f268a40")) {                    Plotly.newPlot(                        "43cab55f-bd85-4587-bca9-5f356f268a40",                        [{"fill":"tozeroy","hovertemplate":"\u003cb\u003eReal\u003c\u002fb\u003e\u003cbr\u003eFrequency: %{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Real","marker":{"color":"#000036"},"mode":"lines","name":"Real","showlegend":true,"x":[-25200000.0,-25149640.0,-25099280.0,-25048920.0,-24998560.0,-24948200.0,-24897840.0,-24847480.0,-24797120.0,-24746760.0,-24696400.0,-24646040.0,-24595680.0,-24545320.0,-24494960.0,-24444600.0,-24394240.0,-24343880.0,-24293520.0,-24243160.0,-24192800.0,-24142440.0,-24092080.0,-24041720.0,-23991360.0,-23941000.0,-23890640.0,-23840280.0,-23789920.0,-23739560.0,-23689200.0,-23638840.0,-23588480.0,-23538120.0,-23487760.0,-23437400.0,-23387040.0,-23336680.0,-23286320.0,-23235960.0,-23185600.0,-23135240.0,-23084880.0,-23034520.0,-22984160.0,-22933800.0,-22883440.0,-22833080.0,-22782720.0,-22732360.0,-22682000.0,-22631640.0,-22581280.0,-22530920.0,-22480560.0,-22430200.0,-22379840.0,-22329480.0,-22279120.0,-22228760.0,-22178400.0,-22128040.0,-22077680.0,-22027320.0,-21976960.0,-21926600.0,-21876240.0,-21825880.0,-21775520.0,-21725160.0,-21674800.0,-21624440.0,-21574080.0,-21523720.0,-21473360.0,-21423000.0,-21372640.0,-21322280.0,-21271920.0,-21221560.0,-21171200.0,-21120840.0,-21070480.
    p와 q는 각 요소가 대응되는 동일한 길이의 확률 분포여야 합니다.
    NaN을 방지하기 위해 epsilon 값을 추가하여 안정화합니다.
    """
    # 작은 값을 더해줌으로써 NaN 방지
    p = np.asarray(p, dtype=np.float64) + epsilon
    q = np.asarray(q, dtype=np.float64) + epsilon

    # 두 분포를 다시 확률 분포로 정상화 (합이 1이 되도록)
    p /= p.sum()
    q /= q.sum()

    # Jensen-Shannon Divergence 계산
    jsd = jensenshannon(p, q, base=base) ** 2  # 결과는 sqrt(JSD)로 반환되므로 제곱하여 JSD로 변환
    return jsd


# 그래프에 추가할 컬럼 목록
columns = ['Transaction_Amount', 'Account_initial_balance', 'Account_balance',
           'Account_remaining_amount_daily_limit_exceeded', 'Account_one_month_max_amount',
           'Account_one_month_std_dev', 'Account_dawn_one_month_max_amount',
           'Time_difference_seconds', 'Account_dawn_one_month_std_dev']

for x in types:
    col_score = 0
    col_cnt = 0
    print(x)
    subset = saved_train[saved_train["Fraud_Type"] == x]
    syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == x]

    subset['Time_difference_seconds'] = pd.to_timedelta(subset['Time_difference']).dt.total_seconds()
    syn_subset['Time_difference_seconds'] = pd.to_timedelta(syn_subset['Time_difference']).dt.total_seconds()

    for col in columns:
        # 연속형 변수 예시
        real_data = subset[col].values
        synth_data = syn_subset[col].values

        # 두 데이터셋의 최소, 최대 범위 설정
        data_min = min(real_data.min(), synth_data.min())
        data_max = max(real_data.max(), synth_data.max())

        # 히스토그램으로 나눌 bins 설정
        bins = np.linspace(data_min, data_max, 20)

        # 각 bins에 대한 확률 밀도 계산
        real_hist, _ = np.histogram(real_data, bins=bins, density=True)
        synth_hist, _ = np.histogram(synth_data, bins=bins, density=True)

        # Inverse KLD / JSD 계산
        result = calculate_jsd(real_hist, synth_hist)
        if np.isnan(result):
            continue
        col_score += result
        col_cnt += 1
        print(col, result)

    # 1일수록 두 분포 차이가 있음. 0은 완전 동일.
    statis.loc[statis['Fraud_Type'] == x, 'Conti_statis'] = col_score / col_cnt
    print("------------------")
# Out:
# m
# Transaction_Amount 0.6029494945056523
# Account_initial_balance 0.09147456210202345
# Account_balance 0.17801463639373316
# Account_remaining_amount_daily_limit_exceeded 0.3495530826571019
# Account_one_month_max_amount 0.17125958959628423
# Account_one_month_std_dev 0.1650022730760873
# Account_dawn_one_month_max_amount 0.08732398769013944
# Time_difference_seconds 2.2375767575891024e-06
# Account_dawn_one_month_std_dev 0.0996377537896903
# ------------------
# a
# Transaction_Amount 0.19585374557401494
# Account_initial_balance 0.11633323850773893
# Account_balance 0.2656674899278528
# Account_remaining_amount_daily_limit_exceeded 0.0451002167608028
# Account_one_month_max_amount 0.20005350764226804
# Account_one_month_std_dev 0.17720774644951434
# Account_dawn_one_month_max_amount 0.07173518476028153
# Time_difference_seconds 0.00402278283714032
# Account_dawn_one_month_std_dev 0.06780885807018766
# ------------------
# j
# Transaction_Amount 0.382595852794383
# Account_initial_balance 0.09753870907274069
# Account_balance 0.09243551758909599
# Account_remaining_amount_daily_limit_exceeded 0.042846968115489076
# Account_one_month_max_amount 0.11416968471614437
# Account_one_month_std_dev 0.15262941883691367
# Account_dawn_one_month_max_amount 0.07419190502167723
# Time_difference_seconds 0.013593886154205764
# Account_dawn_one_month_std_dev 0.08267417000747285
# ------------------
# h
# Transaction_Amount 0.17055160993230092
# Account_initial_balance 0.038703728343315986
# Account_balance 0.11505731882820652
# Account_remaining_amount_daily_limit_exceeded 0.11323347767595011
# Account_one_month_max_amount 0.10216626396003005
# Time_difference_seconds 0.08635021542624043
# ------------------
# k
# Transaction_Amount 0.35471985937135225
# Account_initial_balance 0.07921905701999077
# Account_balance 0.07573389582095598
# Account_remaining_amount_daily_limit_exceeded 0.08906167176869054
# Account_one_month_max_amount 0.1063688420295165
# Account_one_month_std_dev 0.1491637020577542
# Account_dawn_one_month_max_amount 0.09903178054646498
# Time_difference_seconds 0.04727651008420366
# Account_dawn_one_month_std_dev 0.09605191596016617
# ------------------
# c
# Transaction_Amount 0.4220714245221602
# Account_initial_balance 0.14686946896574707
# Account_balance 0.19265485182588923
# Account_remaining_amount_daily_limit_exceeded 0.057786541348832425
# Account_one_month_max_amount 0.15926415468294433
# Account_one_month_std_dev 0.28396803364629686
# Account_dawn_one_month_max_amount 0.07440723277889534
# Time_difference_seconds 0.010073819060192344
# Account_dawn_one_month_std_dev 0.04750989986921176
# ------------------
# g
# Transaction_Amount 0.36885972712240694
# Account_initial_balance 0.06925520572359402
# Account_balance 0.08581399753179283
# Account_remaining_amount_daily_limit_exceeded 0.01708329214280241
# Account_one_month_max_amount 0.11327486814639055
# Account_one_month_std_dev 0.1705046071947638
# Account_dawn_one_month_max_amount 0.06936035821682154
# Time_difference_seconds 0.08855809945347838
# Account_dawn_one_month_std_dev 0.07336492244850243
# ------------------
# i
# Transaction_Amount 0.2361033224969061
# Account_initial_balance 0.11204323949187235
# Account_balance 0.12503566352010131
# Account_remaining_amount_daily_limit_exceeded 0.14335759738371848
# Account_one_month_max_amount 0.12905253029826633
# Account_one_month_std_dev 0.11997096304144064
# Account_dawn_one_month_max_amount 0.1949175244093625
# Time_difference_seconds 0.07940861274412271
# Account_dawn_one_month_std_dev 0.1562370718130468
# ------------------
# b
# Transaction_Amount 0.3622437570614847
# Account_initial_balance 0.10213215628108434
# Account_balance 0.12421468074082753
# Account_one_month_max_amount 0.14079669964326977
# Account_one_month_std_dev 0.19213356009405333
# Account_dawn_one_month_max_amount 0.10796680643987981
# Time_difference_seconds 0.02434110596944517
# Account_dawn_one_month_std_dev 0.07540494203381888
# ------------------
# f
# Transaction_Amount 0.21677729862506057
# Account_initial_balance 0.06304138794134109
# Account_balance 0.0780351359096065
# Account_remaining_amount_daily_limit_exceeded 0.09293621469013373
# Account_one_month_max_amount 0.1583205992042463
# Account_one_month_std_dev 0.07381181365407011
# Time_difference_seconds 0.09877660598138094
# ------------------
# d
# Transaction_Amount 0.3746704576979473
# Account_initial_balance 0.16942626926416182
# Account_balance 0.18742917421258506
# Account_remaining_amount_daily_limit_exceeded 0.11440079244849255
# Account_one_month_max_amount 0.10991866043911447
# Account_one_month_std_dev 0.10446982397027368
# Account_dawn_one_month_max_amount 0.12648045253761767
# Time_difference_seconds 0.01714653041523491
# Account_dawn_one_month_std_dev 0.08296461562103508
# ------------------
# e
# Transaction_Amount 0.30902053673473706
# Account_initial_balance 0.13466251514401745
# Account_balance 0.12371877595510224
# Account_remaining_amount_daily_limit_exceeded 0.19166202338529423
# Account_one_month_max_amount 0.049880032542984724
# Account_one_month_std_dev 0.1282448697768816
# Time_difference_seconds 0.11219437448856985
# ------------------
# l
# Transaction_Amount 0.329245714168523
# Account_initial_balance 0.15728013680711156
# Account_balance 0.03723100166444203
# Account_one_month_max_amount 0.11749450357020426
# Account_one_month_std_dev 0.0787280423945299
# Account_dawn_one_month_max_amount 0.10487035108045993
# Time_difference_seconds 0.034931811739904894
# Account_dawn_one_month_std_dev 0.12808364033292965
# ------------------

# %%
statis
# Out:
#    Fraud_Type  Data_Quality  Data_Diagnostic  Conti_statis  Cate_statis
# 0           m      0.000000         0.000000      0.193913            0
# 1           a      0.654851         0.991672      0.127087            0
# 2           j      0.701725         0.992794      0.116964            0
# 3           h      0.730080         0.999973      0.104344            0
# 4           k      0.685878         0.991663      0.121847            0
# 5           c      0.671822         1.000000      0.154956            0
# 6           g      0.704361         0.993717      0.117342            0
# 7           i      0.696058         0.993125      0.144014            0
# 8           b      0.705124         0.999999      0.141154            0
# 9           f      0.743384         1.000000      0.111671            0
# 10          d      0.700025         1.000000      0.142990            0
# 11          e      0.718118         1.000000      0.149912            0
# 12          l      0.702907         0.999899      0.123483            0

# %%
from scipy.spatial.distance import jensenshannon

# 실제 데이터셋과 합성 데이터셋
cate_cols = ['Customer_Gender', 'Customer_personal_identifier', 'Customer_identification_number', 'Customer_credit_rating',
             'Customer_loan_type', 'Account_account_number', 'Account_account_type', 'Channel', 'Operating_System', 'Error_Code',
             'Type_General_Automatic', 'IP_Address', 'MAC_Address', 'Access_Medium', 'Location', 'Recipient_Account_Number',
             ]

binary_cols = ['Customer_flag_change_of_authentication_1', 'Customer_flag_change_of_authentication_2', 'Customer_flag_change_of_authentication_3',
               'Customer_flag_change_of_authentication_4','Customer_rooting_jailbreak_indicator', 'Customer_mobile_roaming_indicator', 'Customer_VPN_Indicator',
               'Customer_flag_terminal_malicious_behavior_1', 'Customer_flag_terminal_malicious_behavior_2', 'Customer_flag_terminal_malicious_behavior_3',
               'Customer_flag_terminal_malicious_behavior_4', 'Customer_flag_terminal_malicious_behavior_5', 'Customer_flag_terminal_malicious_behavior_6',
               'Customer_inquery_atm_limit', 'Customer_increase_atm_limit', 'Account_indicator_release_limit_excess', 'Account_indicator_Openbanking',
               'Account_release_suspention', 'Transaction_Failure_Status', 'Another_Person_Account', 'Unused_terminal_status', 'First_time_iOS_by_vulnerable_user',
               'Flag_deposit_more_than_tenMillion', 'Unused_account_status', 'Recipient_account_suspend_status'
               ]

# 그래프에 추가할 컬럼 목록
columns = cate_cols + binary_cols

for x in types:
    col_score = 0
    col_cnt = 0
    print(x)
    subset = saved_train[saved_train["Fraud_Type"] == x]
    syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == x]

    for col in columns:
        # 연속형 변수 예시
        real_data = subset[col]
        synth_data = syn_subset[col]

        # 두 데이터셋의 카테고리별 빈도 계산
        real_counts = real_data.value_counts(normalize=True)
        synth_counts = synth_data.value_counts(normalize=True)

        # 빈도 테이블을 맞추기 위해 누락된 카테고리를 0으로 채움
        all_categories = real_counts.index.union(synth_counts.index)
        real_counts = real_counts.reindex(all_categories, fill_value=0)
        synth_counts = synth_counts.reindex(all_categories, fill_value=0)

        # JSD 계산
        result = jensenshannon(real_counts, synth_counts) ** 2  # JSD 계산

        col_score += result
        col_cnt += 1
        print(col, result)

    # 1일수록 두 분포 차이가 있음. 0은 완전 동일.
    statis.loc[statis['Fraud_Type'] == x, 'Cate_statis'] = col_score / col_cnt
    print("------------------")
# Out:
# m
# Customer_Gender 0.03163455063795592
# Customer_personal_identifier 0.6417063421957978
# Customer_identification_number 0.6742016914929496
# Customer_credit_rating 0.04724525644049831
# Customer_loan_type 0.08501713156054483
# Account_account_number 0.6740101073895124
# Account_account_type 0.06441456865432121
# Channel 0.15201748171141968
# Operating_System 0.08803257312259258
# Error_Code 0.008134807220897575
# Type_General_Automatic 0.01938993944472455
# IP_Address 0.6931323833786625
# MAC_Address 0.6916576097657141
# Access_Medium 0.0432073994910192
# Location 0.6872734430305331
# Recipient_Account_Number 0.6850721440125512
# Customer_flag_change_of_authentication_1 0.00022391165726988113
# Customer_flag_change_of_authentication_2 0.026807632644922332
# Customer_flag_change_of_authentication_3 0.002093490554626019
# Customer_flag_change_of_authentication_4 0.03471192278410861
# Customer_rooting_jailbreak_indicator 0.025928572897128167
# Customer_mobile_roaming_indicator 0.011517370425953025
# Customer_VPN_Indicator 0.025568416492456527
# Customer_flag_terminal_malicious_behavior_1 0.017867193009390412
# Customer_flag_terminal_malicious_behavior_2 0.031933119460600526
# Customer_flag_terminal_malicious_behavior_3 0.03309758815256204
# Customer_flag_terminal_malicious_behavior_4 0.02203571783171122
# Customer_flag_terminal_malicious_behavior_5 0.019167823972080927
# Customer_flag_terminal_malicious_behavior_6 0.04636588193351426
# Customer_inquery_atm_limit 0.04206963037961528
# Customer_increase_atm_limit 0.05238134859687124
# Account_indicator_release_limit_excess 0.004633042489825239
# Account_indicator_Openbanking 0.0023429798077131306
# Account_release_suspention 0.01748409425521392
# Transaction_Failure_Status 0.008134807220897575
# Another_Person_Account 0.0
# Unused_terminal_status 0.028172567316710327
# First_time_iOS_by_vulnerable_user 9.044438201872429e-05
# Flag_deposit_more_than_tenMillion 0.11770454345379323
# Unused_account_status 0.019413381348705714
# Recipient_account_suspend_status 0.15982459396214344
# ------------------
# a
# Customer_Gender 0.016883584060205084
# Customer_personal_identifier 0.3642228332138309
# Customer_identification_number 0.3675722811865629
# Customer_credit_rating 0.062567122621
# Customer_loan_type 0.04966244017189299
# Account_account_number 0.36935253320080347
# Account_account_type 0.024969316022123652
# Channel 0.1007690060955203
# Operating_System 0.09700059095018455
# Error_Code 0.006859537450681694
# Type_General_Automatic 0.014478760217470858
# IP_Address 0.6931471805599452
# MAC_Address 0.3678872541472436
# Access_Medium 0.03829307269488696
# Location 0.361596710129694
# Recipient_Account_Number 0.36746703191677754
# Customer_flag_change_of_authentication_1 0.00294243305741337
# Customer_flag_change_of_authentication_2 0.0172471600145602
# Customer_flag_change_of_authentication_3 0.009578758465381684
# Customer_flag_change_of_authentication_4 0.03400273499340032
# Customer_rooting_jailbreak_indicator 0.027829505727016583
# Customer_mobile_roaming_indicator 0.010511425321212927
# Customer_VPN_Indicator 0.03561043777310789
# Customer_flag_terminal_malicious_behavior_1 0.029823223644474497
# Customer_flag_terminal_malicious_behavior_2 0.03369092909599239
# Customer_flag_terminal_malicious_behavior_3 0.011309118746425175
# Customer_flag_terminal_malicious_behavior_4 0.015550883541682232
# Customer_flag_terminal_malicious_behavior_5 0.040127365433842294
# Customer_flag_terminal_malicious_behavior_6 0.018424944499116185
# Customer_inquery_atm_limit 0.010232960124880836
# Customer_increase_atm_limit 0.017022344206738524
# Account_indicator_release_limit_excess 0.022759703855084766
# Account_indicator_Openbanking 0.006981977714981405
# Account_release_suspention 0.0006937457607661002
# Transaction_Failure_Status 0.007048132224835807
# Another_Person_Account 0.0
# Unused_terminal_status 0.032028112181952666
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.001466445489918963
# Unused_account_status 0.033869146858535745
# Recipient_account_suspend_status 0.0004411566998689265
# ------------------
# j
# Customer_Gender 0.06496595463907748
# Customer_personal_identifier 0.40399293264678876
# Customer_identification_number 0.41674952448343955
# Customer_credit_rating 0.05944169272044148
# Customer_loan_type 0.07319701009891509
# Account_account_number 0.4181460559276073
# Account_account_type 0.15686326030967948
# Channel 0.011512142914721598
# Operating_System 0.07828474737608583
# Error_Code 0.021258406929464593
# Type_General_Automatic 0.03597375665014844
# IP_Address 0.6931471805599451
# MAC_Address 0.42133759603806636
# Access_Medium 0.12680890789739985
# Location 0.4143894204794521
# Recipient_Account_Number 0.414801756652715
# Customer_flag_change_of_authentication_1 0.0024245156624866718
# Customer_flag_change_of_authentication_2 0.03753223385306883
# Customer_flag_change_of_authentication_3 0.01742320288049555
# Customer_flag_change_of_authentication_4 0.048080634164371666
# Customer_rooting_jailbreak_indicator 0.016616352207601336
# Customer_mobile_roaming_indicator 0.006981977714981405
# Customer_VPN_Indicator 0.021258406929464593
# Customer_flag_terminal_malicious_behavior_1 0.006981977714981405
# Customer_flag_terminal_malicious_behavior_2 0.017649227464594814
# Customer_flag_terminal_malicious_behavior_3 0.027925427809961725
# Customer_flag_terminal_malicious_behavior_4 0.0175406304459989
# Customer_flag_terminal_malicious_behavior_5 0.022454701929899776
# Customer_flag_terminal_malicious_behavior_6 0.02168846683839775
# Customer_inquery_atm_limit 0.022675590105042324
# Customer_increase_atm_limit 0.06233125958618739
# Account_indicator_release_limit_excess 0.0004509347699032358
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.06285900141021494
# Transaction_Failure_Status 0.021258406929464593
# Another_Person_Account 0.0
# Unused_terminal_status 0.017649227464594814
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.01123462907595759
# Unused_account_status 0.0
# Recipient_account_suspend_status 0.0
# ------------------
# h
# Customer_Gender 0.05867264249083021
# Customer_personal_identifier 0.4153878555677202
# Customer_identification_number 0.41390267589376295
# Customer_credit_rating 0.09669121241576319
# Customer_loan_type 0.107552254554987
# Account_account_number 0.41271403922314703
# Account_account_type 0.02764776981685184
# Channel 0.03383291581457766
# Operating_System 0.10669236394599829
# Error_Code 0.001036086588117496
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.41283095457459357
# Access_Medium 0.03860817968437609
# Location 0.4129063824468453
# Recipient_Account_Number 0.42192417927004616
# Customer_flag_change_of_authentication_1 0.007717441335823103
# Customer_flag_change_of_authentication_2 0.000808116411577839
# Customer_flag_change_of_authentication_3 0.0002754525729865599
# Customer_flag_change_of_authentication_4 0.002370634444181036
# Customer_rooting_jailbreak_indicator 0.02092165441322111
# Customer_mobile_roaming_indicator 0.006701093134139202
# Customer_VPN_Indicator 0.017649227464594814
# Customer_flag_terminal_malicious_behavior_1 0.006981977714981405
# Customer_flag_terminal_malicious_behavior_2 0.020326436686877395
# Customer_flag_terminal_malicious_behavior_3 0.0318944340822276
# Customer_flag_terminal_malicious_behavior_4 0.03405978647592553
# Customer_flag_terminal_malicious_behavior_5 0.018215199816379566
# Customer_flag_terminal_malicious_behavior_6 0.015460176249021578
# Customer_inquery_atm_limit 4.3969405568591657e-07
# Customer_increase_atm_limit 0.002036696970846704
# Account_indicator_release_limit_excess 0.036116780002689336
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.08227260308829717
# Transaction_Failure_Status 0.0008720694504981879
# Another_Person_Account 0.0
# Unused_terminal_status 0.0390571085639459
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.022280799952932886
# Unused_account_status 5.309468797900152e-05
# Recipient_account_suspend_status 0.001951665489135524
# ------------------
# k
# Customer_Gender 0.026378901120329985
# Customer_personal_identifier 0.4075371580692741
# Customer_identification_number 0.4256451336847501
# Customer_credit_rating 0.056596587338162585
# Customer_loan_type 0.09498185100482306
# Account_account_number 0.4232754060761957
# Account_account_type 0.11521166935725342
# Channel 0.05775041820281229
# Operating_System 0.051707016151364776
# Error_Code 0.005434003359899328
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.4247171442965576
# Access_Medium 0.02175037575037367
# Location 0.41744127928010394
# Recipient_Account_Number 0.4166560289595266
# Customer_flag_change_of_authentication_1 0.01774848029688862
# Customer_flag_change_of_authentication_2 0.023086127992889637
# Customer_flag_change_of_authentication_3 0.04229021048833721
# Customer_flag_change_of_authentication_4 0.010263885227644142
# Customer_rooting_jailbreak_indicator 0.03597375665014844
# Customer_mobile_roaming_indicator 0.017649227464594814
# Customer_VPN_Indicator 0.03597375665014844
# Customer_flag_terminal_malicious_behavior_1 0.0052700398120408675
# Customer_flag_terminal_malicious_behavior_2 0.06548680217408893
# Customer_flag_terminal_malicious_behavior_3 0.03225222523462623
# Customer_flag_terminal_malicious_behavior_4 0.04731574840969632
# Customer_flag_terminal_malicious_behavior_5 0.04061758849155109
# Customer_flag_terminal_malicious_behavior_6 0.03239792530992673
# Customer_inquery_atm_limit 0.02926100450683659
# Customer_increase_atm_limit 0.029085678490557515
# Account_indicator_release_limit_excess 0.019343321343605606
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.03791045410724691
# Transaction_Failure_Status 0.005313487076265543
# Another_Person_Account 0.0
# Unused_terminal_status 0.027652194871471962
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0845304185796488
# Unused_account_status 0.0
# Recipient_account_suspend_status 0.002522076763532902
# ------------------
# c
# Customer_Gender 0.020515458340325532
# Customer_personal_identifier 0.37484450841510425
# Customer_identification_number 0.3785235355415128
# Customer_credit_rating 0.12207831708589574
# Customer_loan_type 0.08871758899021631
# Account_account_number 0.37994930149863376
# Account_account_type 0.019754568088680622
# Channel 0.018025893177120663
# Operating_System 0.06387387586843189
# Error_Code 0.013504257437395374
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.38998334805289164
# Access_Medium 0.09739445615593866
# Location 0.38697386332087763
# Recipient_Account_Number 0.39209840060041606
# Customer_flag_change_of_authentication_1 0.08993324937883017
# Customer_flag_change_of_authentication_2 0.04282838247066575
# Customer_flag_change_of_authentication_3 0.025418919605270977
# Customer_flag_change_of_authentication_4 0.026381259230643512
# Customer_rooting_jailbreak_indicator 0.0016254185852891522
# Customer_mobile_roaming_indicator 0.010047954434068663
# Customer_VPN_Indicator 0.006981977714981405
# Customer_flag_terminal_malicious_behavior_1 0.01252897576554491
# Customer_flag_terminal_malicious_behavior_2 0.012244933583408177
# Customer_flag_terminal_malicious_behavior_3 0.012995713953288144
# Customer_flag_terminal_malicious_behavior_4 0.03650399428194242
# Customer_flag_terminal_malicious_behavior_5 0.0027777287342559635
# Customer_flag_terminal_malicious_behavior_6 0.040554052702830454
# Customer_inquery_atm_limit 0.055025482019131225
# Customer_increase_atm_limit 0.03006464990625253
# Account_indicator_release_limit_excess 0.06229044950917606
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.003499680260646725
# Transaction_Failure_Status 0.013504257437395374
# Another_Person_Account 0.0
# Unused_terminal_status 0.03635980855861292
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0002453513860951771
# Unused_account_status 0.009473613075333993
# Recipient_account_suspend_status 0.00023137740961618174
# ------------------
# g
# Customer_Gender 0.00019277729585729338
# Customer_personal_identifier 0.3928346277956111
# Customer_identification_number 0.40557755262587647
# Customer_credit_rating 0.07811674804396788
# Customer_loan_type 0.07055044782238001
# Account_account_number 0.40837912328400316
# Account_account_type 0.10383497382030156
# Channel 0.05650002194792223
# Operating_System 0.11005074825833043
# Error_Code 0.006981977714981405
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599452
# MAC_Address 0.4039310394704444
# Access_Medium 0.05499693681032051
# Location 0.40735295493713936
# Recipient_Account_Number 0.4084141968160999
# Customer_flag_change_of_authentication_1 0.06483147033091995
# Customer_flag_change_of_authentication_2 0.005964543422053585
# Customer_flag_change_of_authentication_3 0.03516443320005192
# Customer_flag_change_of_authentication_4 0.03225222523462623
# Customer_rooting_jailbreak_indicator 0.031343484348581196
# Customer_mobile_roaming_indicator 0.014067039412645505
# Customer_VPN_Indicator 0.025659250633457805
# Customer_flag_terminal_malicious_behavior_1 0.014067039412645505
# Customer_flag_terminal_malicious_behavior_2 0.019252886883916413
# Customer_flag_terminal_malicious_behavior_3 0.031605904536539615
# Customer_flag_terminal_malicious_behavior_4 0.011675736100986
# Customer_flag_terminal_malicious_behavior_5 0.033906901486596704
# Customer_flag_terminal_malicious_behavior_6 0.019526036166888028
# Customer_inquery_atm_limit 0.0004335439051874551
# Customer_increase_atm_limit 0.0035256918411135443
# Account_indicator_release_limit_excess 0.07637307788183788
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.0
# Transaction_Failure_Status 0.006981977714981405
# Another_Person_Account 0.0
# Unused_terminal_status 0.030158854304426445
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0
# Unused_account_status 0.008440334613692828
# Recipient_account_suspend_status 0.022387267040587966
# ------------------
# i
# Customer_Gender 0.056681952755940186
# Customer_personal_identifier 0.37117818100946715
# Customer_identification_number 0.38911725904961575
# Customer_credit_rating 0.07222318207292247
# Customer_loan_type 0.06285176506280542
# Account_account_number 0.38646493889030437
# Account_account_type 0.07038428975186008
# Channel 0.010282993981798133
# Operating_System 0.08315388174552013
# Error_Code 0.0
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.3951004710211018
# Access_Medium 0.049407031024826104
# Location 0.3933224634763895
# Recipient_Account_Number 0.3958719231341466
# Customer_flag_change_of_authentication_1 0.028559461849879304
# Customer_flag_change_of_authentication_2 0.006981977714981405
# Customer_flag_change_of_authentication_3 0.015205136628376819
# Customer_flag_change_of_authentication_4 0.006981977714981405
# Customer_rooting_jailbreak_indicator 0.021258406929464593
# Customer_mobile_roaming_indicator 0.010511425321212927
# Customer_VPN_Indicator 0.021588699081432176
# Customer_flag_terminal_malicious_behavior_1 0.014067039412645505
# Customer_flag_terminal_malicious_behavior_2 0.024550293067867247
# Customer_flag_terminal_malicious_behavior_3 0.01622591109340084
# Customer_flag_terminal_malicious_behavior_4 0.030018949095759955
# Customer_flag_terminal_malicious_behavior_5 0.030018949095759955
# Customer_flag_terminal_malicious_behavior_6 0.00013394974987053542
# Customer_inquery_atm_limit 0.014067039412645505
# Customer_increase_atm_limit 0.016616352207601336
# Account_indicator_release_limit_excess 0.045640244658470996
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.03156523482255475
# Transaction_Failure_Status 0.0
# Another_Person_Account 0.0
# Unused_terminal_status 0.01173762775218764
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 3.9608660477695116e-05
# Unused_account_status 0.0024527308088759386
# Recipient_account_suspend_status 0.025742056969870915
# ------------------
# b
# Customer_Gender 0.0006566849182855512
# Customer_personal_identifier 0.38041429238395624
# Customer_identification_number 0.37913279598896166
# Customer_credit_rating 0.06640456220538317
# Customer_loan_type 0.05931626118410424
# Account_account_number 0.3794938693252223
# Account_account_type 0.1044797994561874
# Channel 0.009844032887713548
# Operating_System 0.04613540290678893
# Error_Code 0.006981977714981405
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.383090080822989
# Access_Medium 0.017888781760018433
# Location 0.3857790718246598
# Recipient_Account_Number 0.3803620344206485
# Customer_flag_change_of_authentication_1 0.00261468992166493
# Customer_flag_change_of_authentication_2 0.02202970192807959
# Customer_flag_change_of_authentication_3 0.00033727550881232707
# Customer_flag_change_of_authentication_4 0.011809654674446848
# Customer_rooting_jailbreak_indicator 0.0017739469336190176
# Customer_mobile_roaming_indicator 0.05148560391831269
# Customer_VPN_Indicator 0.012630269873568273
# Customer_flag_terminal_malicious_behavior_1 0.02870826739542482
# Customer_flag_terminal_malicious_behavior_2 0.045790608107615816
# Customer_flag_terminal_malicious_behavior_3 0.005957908567748889
# Customer_flag_terminal_malicious_behavior_4 0.0418369108600139
# Customer_flag_terminal_malicious_behavior_5 0.022973733077733215
# Customer_flag_terminal_malicious_behavior_6 0.02839595123812327
# Customer_inquery_atm_limit 0.028495155197046568
# Customer_increase_atm_limit 0.040496778587338945
# Account_indicator_release_limit_excess 0.04320177725575753
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.016796588273301032
# Transaction_Failure_Status 0.006981977714981405
# Another_Person_Account 0.0
# Unused_terminal_status 0.021852995695223927
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0024867616422522
# Unused_account_status 0.0070779732436187315
# Recipient_account_suspend_status 0.00011789552603708651
# ------------------
# f
# Customer_Gender 0.005161788290438663
# Customer_personal_identifier 0.39028828627536305
# Customer_identification_number 0.3823961626252433
# Customer_credit_rating 0.04805516098240833
# Customer_loan_type 0.03450048288535525
# Account_account_number 0.38193602353364975
# Account_account_type 0.09320687028992908
# Channel 0.0
# Operating_System 0.0025292282716425254
# Error_Code 0.010511425321212927
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.38310741414041
# Access_Medium 0.06940374083474363
# Location 0.3819541852858625
# Recipient_Account_Number 0.38311147857340294
# Customer_flag_change_of_authentication_1 0.010407211026873113
# Customer_flag_change_of_authentication_2 0.04607281991672771
# Customer_flag_change_of_authentication_3 0.007977439701509536
# Customer_flag_change_of_authentication_4 0.017417754586195253
# Customer_rooting_jailbreak_indicator 0.0
# Customer_mobile_roaming_indicator 0.0
# Customer_VPN_Indicator 0.0
# Customer_flag_terminal_malicious_behavior_1 0.0
# Customer_flag_terminal_malicious_behavior_2 0.0
# Customer_flag_terminal_malicious_behavior_3 0.0
# Customer_flag_terminal_malicious_behavior_4 0.0
# Customer_flag_terminal_malicious_behavior_5 0.0
# Customer_flag_terminal_malicious_behavior_6 0.0
# Customer_inquery_atm_limit 0.0363668866460412
# Customer_increase_atm_limit 0.02605736317288871
# Account_indicator_release_limit_excess 0.0020984430997351075
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.006981977714981405
# Transaction_Failure_Status 0.010511425321212927
# Another_Person_Account 0.0
# Unused_terminal_status 0.003478298769743019
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0
# Unused_account_status 0.013945911309668045
# Recipient_account_suspend_status 0.003815704794659515
# ------------------
# d
# Customer_Gender 0.0012048296002088472
# Customer_personal_identifier 0.39121247249777763
# Customer_identification_number 0.39749345596289914
# Customer_credit_rating 0.04211751319452401
# Customer_loan_type 0.05912637160622819
# Account_account_number 0.3960084033686727
# Account_account_type 0.053304331243140185
# Channel 0.04950462176740155
# Operating_System 0.10475150965058344
# Error_Code 0.0
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.3997964506131731
# Access_Medium 0.008552430152499194
# Location 0.39506830055581715
# Recipient_Account_Number 0.3954613277703638
# Customer_flag_change_of_authentication_1 0.0023009147151221918
# Customer_flag_change_of_authentication_2 0.01733604080138815
# Customer_flag_change_of_authentication_3 0.009984759104087705
# Customer_flag_change_of_authentication_4 0.006904458431137973
# Customer_rooting_jailbreak_indicator 0.014067039412645505
# Customer_mobile_roaming_indicator 0.0058305282949772655
# Customer_VPN_Indicator 0.018758330920139787
# Customer_flag_terminal_malicious_behavior_1 0.010511425321212927
# Customer_flag_terminal_malicious_behavior_2 0.027669140595729922
# Customer_flag_terminal_malicious_behavior_3 0.03561043777310789
# Customer_flag_terminal_malicious_behavior_4 0.009117265235543076
# Customer_flag_terminal_malicious_behavior_5 0.03225222523462623
# Customer_flag_terminal_malicious_behavior_6 0.013608904655221722
# Customer_inquery_atm_limit 0.0012709999967936922
# Customer_increase_atm_limit 0.0023845993875004617
# Account_indicator_release_limit_excess 0.07217178920148545
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.0005410677864878776
# Transaction_Failure_Status 0.0
# Another_Person_Account 0.0
# Unused_terminal_status 0.0
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.007552420054142757
# Unused_account_status 0.0028528969774309007
# Recipient_account_suspend_status 0.07926879304375839
# ------------------
# e
# Customer_Gender 0.024838995345329875
# Customer_personal_identifier 0.4175959058999969
# Customer_identification_number 0.4203918088511953
# Customer_credit_rating 0.03429616114584949
# Customer_loan_type 0.07741877383762706
# Account_account_number 0.42413359555146557
# Account_account_type 0.152701340115464
# Channel 0.0
# Operating_System 0.017545360573206083
# Error_Code 0.02092165441322111
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.42097212113420474
# Access_Medium 0.10464903606605601
# Location 0.4190738747450697
# Recipient_Account_Number 0.4231394255010957
# Customer_flag_change_of_authentication_1 0.02016384017670266
# Customer_flag_change_of_authentication_2 0.035435177181501756
# Customer_flag_change_of_authentication_3 0.09055456226431798
# Customer_flag_change_of_authentication_4 0.02506480217111187
# Customer_rooting_jailbreak_indicator 0.02773399297870135
# Customer_mobile_roaming_indicator 0.0
# Customer_VPN_Indicator 0.0
# Customer_flag_terminal_malicious_behavior_1 0.0
# Customer_flag_terminal_malicious_behavior_2 0.00983529220935883
# Customer_flag_terminal_malicious_behavior_3 0.0
# Customer_flag_terminal_malicious_behavior_4 0.0
# Customer_flag_terminal_malicious_behavior_5 0.0
# Customer_flag_terminal_malicious_behavior_6 0.016809850458325483
# Customer_inquery_atm_limit 0.029702645046470414
# Customer_increase_atm_limit 0.012598016736942623
# Account_indicator_release_limit_excess 0.011067542685740367
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.017649227464594814
# Transaction_Failure_Status 0.02092165441322111
# Another_Person_Account 0.0
# Unused_terminal_status 0.017649227464594814
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0
# Unused_account_status 0.06652592168493322
# Recipient_account_suspend_status 2.7456218134038528e-05
# ------------------
# l
# Customer_Gender 0.08065459835235164
# Customer_personal_identifier 0.4120606539484468
# Customer_identification_number 0.4052145903731891
# Customer_credit_rating 0.11610653971703257
# Customer_loan_type 0.02852041720775313
# Account_account_number 0.4057842196295997
# Account_account_type 0.10668064951934048
# Channel 0.1450059443281041
# Operating_System 0.1270264498789639
# Error_Code 0.006981977714981405
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.42168093698415876
# Access_Medium 0.1043768038973718
# Location 0.4182653891057892
# Recipient_Account_Number 0.4203704146014487
# Customer_flag_change_of_authentication_1 0.03225222523462623
# Customer_flag_change_of_authentication_2 0.010511425321212927
# Customer_flag_change_of_authentication_3 0.009402187873885255
# Customer_flag_change_of_authentication_4 0.0183965152575571
# Customer_rooting_jailbreak_indicator 0.0220668372347497
# Customer_mobile_roaming_indicator 0.021258406929464593
# Customer_VPN_Indicator 0.017649227464594814
# Customer_flag_terminal_malicious_behavior_1 0.010511425321212927
# Customer_flag_terminal_malicious_behavior_2 0.03225222523462623
# Customer_flag_terminal_malicious_behavior_3 0.011479546127903256
# Customer_flag_terminal_malicious_behavior_4 0.006981977714981405
# Customer_flag_terminal_malicious_behavior_5 0.028207817483787884
# Customer_flag_terminal_malicious_behavior_6 0.025309566618774974
# Customer_inquery_atm_limit 0.01747552334244199
# Customer_increase_atm_limit 0.0422530186526186
# Account_indicator_release_limit_excess 0.043978364522755685
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.021220857987031192
# Transaction_Failure_Status 0.006981977714981405
# Another_Person_Account 0.0
# Unused_terminal_status 0.03597375665014844
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.06532103140867886
# Unused_account_status 0.008397189006659811
# Recipient_account_suspend_status 0.017530276076944937
# ------------------

# %%
statis
# Out:
#    Fraud_Type  Data_Quality  Data_Diagnostic  Conti_statis  Cate_statis
# 0           m      0.000000         0.000000      0.193913     0.147213
# 1           a      0.654851         0.991672      0.127087     0.090779
# 2           j      0.701725         0.992794      0.116964     0.104326
# 3           h      0.730080         0.999973      0.104344     0.098087
# 4           k      0.685878         0.991663      0.121847     0.104479
# 5           c      0.671822         1.000000      0.154956     0.096851
# 6           g      0.704361         0.993717      0.117342     0.099804
# 7           i      0.696058         0.993125      0.144014     0.092845
# 8           b      0.705124         0.999999      0.141154     0.091146
# 9           f      0.743384         1.000000      0.111671     0.084011
# 10          d      0.700025         1.000000      0.142990     0.091713
# 11          e      0.718118         1.000000      0.149912     0.098843
# 12          l      0.702907         0.999899      0.123483     0.107251

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 8.4 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5

# %% [markdown]
# # Model selection

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.naive_bayes import GaussianNB
from catboost import CatBoostClassifier
import pickle

# 모델 초기화 함수
def get_new_models():
    return {
        'Random_Forest': RandomForestClassifier(n_estimators=100, random_state=42),
        'Logistic_Regression': LogisticRegression(multi_class='ovr', solver='lbfgs', max_iter=1000),
        'Naive_Bayes': GaussianNB(),
        'CatBoost': CatBoostClassifier(iterations=1000, depth=6, learning_rate=0.1, loss_function='MultiClass', random_seed=42),
        'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', objective='multi:softprob')
    }


# SRA 계산 함수 정의
def calculate_sra(X_real_in, y_real, X_syn_in, y_syn):
    # 데이터 분할

    real_scores = {}
    synth_scores = {}
    model_instances = {}

    # 각 모델에 대해 AUROC 점수 계산
    for model_name, model_real in get_new_models().items():
        print("Model: ", model_name)
        X_train_real, X_test_real, y_train_real, y_test_real = train_test_split(X_real_in, y_real, test_size=0.2, random_state=42, stratify=y_real)

        model_real.fit(X_train_real, y_train_real)
        y_pred_real = model_real.predict_proba(X_test_real)
        real_scores[model_name] = roc_auc_score(y_test_real, y_pred_real, multi_class='ovr')
        print('Real: ', real_scores)
        # save
        model_save_name = '4_3_tvae_model_real_' + model_name +'.pkl'
        pickle.dump(model_real, open(model_save_name, "wb"))

        # 합성 데이터에서 모델 학습 및 성능 평가
        X_train_synth, X_test_synth, y_train_synth, y_test_synth = train_test_split(X_syn_in, y_syn, test_size=0.2, random_state=42, stratify=y_syn)

        model_syn = get_new_models()[model_name]  # 모델을 새로 초기화
        model_syn.fit(X_train_synth, y_train_synth)
        y_pred_synth = model_syn.predict_proba(X_test_real)
        synth_scores[model_name] = roc_auc_score(y_test_real, y_pred_synth, multi_class='ovr')
        print('Syn: ', synth_scores)
        # save
        model_save_name = '4_3_tvae_model_syn_' + model_name +'.pkl'
        pickle.dump(model_real, open(model_save_name, "wb"))

        # 모델 인스턴스 저장
        model_instances[model_name] = {'real_model': model_real, 'syn_model': model_syn}

    # 순위 계산
    real_ranking = sorted(real_scores, key=real_scores.get, reverse=True)
    synth_ranking = sorted(synth_scores, key=synth_scores.get, reverse=True)

    return real_scores, synth_scores, real_ranking, synth_ranking, model_instances


# SRA 값 계산
#fraud_type = 'a'

df_real = saved_train.copy()
df_syn = all_synthetic_data.copy()
df_real = df_real.drop('Time_difference_seconds', axis=1)

df_real_m = df_real[df_real.Fraud_Type == 'm'].sample(n=100, random_state=42)
df_real_not_m = df_real[df_real.Fraud_Type != 'm']
df_real_100 = pd.concat([df_real_m, df_real_not_m])

df_syn_m = df_syn[df_syn.Fraud_Type == 'm'].sample(n=100, random_state=42)
df_syn_not_m = df_syn[df_syn.Fraud_Type != 'm']
df_syn_100 = pd.concat([df_syn_m, df_syn_not_m])


###################
X_real = df_real_100.drop(columns=['Fraud_Type'])
y_real = df_real_100['Fraud_Type']

X_syn = df_syn_100.drop(columns=['Fraud_Type'])
y_syn = df_syn_100['Fraud_Type']


# 레이블 정리
le_subclass = LabelEncoder()
train_y_encoded = le_subclass.fit_transform(saved_train.Fraud_Type)
for i, label in enumerate(le_subclass.classes_):
    print(f"원래 레이블: {label}, 변환된 숫자: {i}")

y_real = le_subclass.transform(y_real)
y_syn = le_subclass.transform(y_syn)

# time_difference를 초로 바꾸기
X_real['Time_difference_seconds'] = pd.to_timedelta(X_real['Time_difference']).dt.total_seconds()
X_syn['Time_difference_seconds'] = pd.to_timedelta(X_syn['Time_difference']).dt.total_seconds()

# unique한 코드 지우기
X_real.drop('Customer_personal_identifier', axis=1, inplace=True)
X_syn.drop('Customer_personal_identifier', axis=1, inplace=True)

# 범주형 변수 인코딩
categorical_columns = X_real.select_dtypes(include=['object', 'category']).columns

# 훈련 데이터 인코딩
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X_real[categorical_columns] = ordinal_encoder.fit_transform(X_real[categorical_columns])
X_syn[categorical_columns] = ordinal_encoder.transform(X_syn[categorical_columns])

# 특성 순서 저장
feature_order = X_real.columns.tolist()
####################

real_scores, synth_scores, real_ranking, synth_ranking, models_out = calculate_sra(X_real[feature_order], y_real, X_syn[feature_order], y_syn)
# Out:
# 원래 레이블: a, 변환된 숫자: 0
# 원래 레이블: b, 변환된 숫자: 1
# 원래 레이블: c, 변환된 숫자: 2
# 원래 레이블: d, 변환된 숫자: 3
# 원래 레이블: e, 변환된 숫자: 4
# 원래 레이블: f, 변환된 숫자: 5
# 원래 레이블: g, 변환된 숫자: 6
# 원래 레이블: h, 변환된 숫자: 7
# 원래 레이블: i, 변환된 숫자: 8
# 원래 레이블: j, 변환된 숫자: 9
# 원래 레이블: k, 변환된 숫자: 10
# 원래 레이블: l, 변환된 숫자: 11
# 원래 레이블: m, 변환된 숫자: 12
# Model:  Random_Forest
# Real:  {'Random_Forest': 0.9431650641025642}
# Syn:  {'Random_Forest': 0.8699278846153848}
# Model:  Logistic_Regression
# Real:  {'Random_Forest': 0.9431650641025642, 'Logistic_Regression': 0.7774358974358975}
# Syn:  {'Random_Forest': 0.8699278846153848, 'Logistic_Regression': 0.7190064102564103}
# Model:  Naive_Bayes
# Real:  {'Random_Forest': 0.9431650641025642, 'Logistic_Regression': 0.7774358974358975, 'Naive_Bayes': 0.7818910256410256}
# Syn:  {'Random_Forest': 0.8699278846153848, 'Logistic_Regression': 0.7190064102564103, 'Naive_Bayes': 0.7046474358974358}
# Model:  CatBoost
# 0:	learn: 2.4658552	total: 116ms	remaining: 1m 56s
# 1:	learn: 2.4138873	total: 183ms	remaining: 1m 31s
# 2:	learn: 2.3305589	total: 250ms	remaining: 1m 23s
# 3:	learn: 2.2611016	total: 321ms	remaining: 1m 19s
# 4:	learn: 2.2011874	total: 391ms	remaining: 1m 17s
# 5:	learn: 2.1539700	total: 451ms	remaining: 1m 14s
# 6:	learn: 2.1138173	total: 512ms	remaining: 1m 12s
# 7:	learn: 2.0518443	total: 572ms	remaining: 1m 10s
# 8:	learn: 1.9979911	total: 636ms	remaining: 1m 9s
# 9:	learn: 1.9616276	total: 696ms	remaining: 1m 8s
# 10:	learn: 1.9151573	total: 760ms	remaining: 1m 8s
# 11:	learn: 1.8746147	total: 823ms	remaining: 1m 7s
# 12:	learn: 1.8437380	total: 889ms	remaining: 1m 7s
# 13:	learn: 1.7798808	total: 950ms	remaining: 1m 6s
# 14:	learn: 1.7374816	total: 1.01s	remaining: 1m 6s
# 15:	learn: 1.7117990	total: 1.07s	remaining: 1m 6s
# 16:	learn: 1.6809291	total: 1.14s	remaining: 1m 5s
# 17:	learn: 1.6472643	total: 1.2s	remaining: 1m 5s
# 18:	learn: 1.6221640	total: 1.26s	remaining: 1m 5s
# 19:	learn: 1.5907247	total: 1.33s	remaining: 1m 5s
# 20:	learn: 1.5655787	total: 1.41s	remaining: 1m 5s
# 21:	learn: 1.5456791	total: 1.47s	remaining: 1m 5s
# 22:	learn: 1.5194258	total: 1.53s	remaining: 1m 4s
# 23:	learn: 1.4997154	total: 1.59s	remaining: 1m 4s
# 24:	learn: 1.4833250	total: 1.66s	remaining: 1m 4s
# 25:	learn: 1.4510381	total: 1.76s	remaining: 1m 6s
# 26:	learn: 1.4354866	total: 1.86s	remaining: 1m 6s
# 27:	learn: 1.4192047	total: 1.96s	remaining: 1m 8s
# 28:	learn: 1.3899677	total: 2.07s	remaining: 1m 9s
# 29:	learn: 1.3705417	total: 2.19s	remaining: 1m 10s
# 30:	learn: 1.3558769	total: 2.3s	remaining: 1m 11s
# 31:	learn: 1.3373190	total: 2.43s	remaining: 1m 13s
# 32:	learn: 1.3207257	total: 2.54s	remaining: 1m 14s
# 734:	learn: 0.0631176	total: 1m	remaining: 21.9s
# 735:	learn: 0.0630368	total: 1m	remaining: 21.9s
# 736:	learn: 0.0629310	total: 1m	remaining: 21.8s
# 737:	learn: 0.0627954	total: 1m 1s	remaining: 21.7s
# 738:	learn: 0.0627264	total: 1m 1s	remaining: 21.6s
# 739:	learn: 0.0626198	total: 1m 1s	remaining: 21.5s
# 740:	learn: 0.0624877	total: 1m 1s	remaining: 21.4s
# 741:	learn: 0.0623664	total: 1m 1s	remaining: 21.3s
# 742:	learn: 0.0622410	total: 1m 1s	remaining: 21.2s
# 743:	learn: 0.0621134	total: 1m 1s	remaining: 21.1s
# 744:	learn: 0.0619853	total: 1m 1s	remaining: 21s
# 745:	learn: 0.0618542	total: 1m 1s	remaining: 21s
# 746:	learn: 0.0617028	total: 1m 1s	remaining: 20.9s
# 747:	learn: 0.0615526	total: 1m 1s	remaining: 20.8s
# 748:	learn: 0.0614292	total: 1m 1s	remaining: 20.7s
# 749:	learn: 0.0613250	total: 1m 1s	remaining: 20.6s
# 750:	learn: 0.0612447	total: 1m 2s	remaining: 20.6s
# 751:	learn: 0.0611044	total: 1m 2s	remaining: 20.5s
# 752:	learn: 0.0610228	total: 1m 2s	remaining: 20.4s
# 753:	learn: 0.0608784	total: 1m 2s	remaining: 20.4s
# 754:	learn: 0.0607250	total: 1m 2s	remaining: 20.3s
# 755:	learn: 0.0605647	total: 1m 2s	remaining: 20.2s
# 756:	learn: 0.0603806	total: 1m 2s	remaining: 20.1s
# 757:	learn: 0.0602798	total: 1m 2s	remaining: 20.1s
# 758:	learn: 0.0601969	total: 1m 2s	remaining: 20s
# 759:	learn: 0.0600722	total: 1m 3s	remaining: 19.9s
# 760:	learn: 0.0599827	total: 1m 3s	remaining: 19.9s
# 761:	learn: 0.0598630	total: 1m 3s	remaining: 19.8s
# 762:	learn: 0.0597469	total: 1m 3s	remaining: 19.7s
# 763:	learn: 0.0596279	total: 1m 3s	remaining: 19.6s
# 764:	learn: 0.0595407	total: 1m 3s	remaining: 19.6s
# 765:	learn: 0.0594281	total: 1m 3s	remaining: 19.5s
# 766:	learn: 0.0593084	total: 1m 3s	remaining: 19.4s
# 767:	learn: 0.0592003	total: 1m 4s	remaining: 19.3s
# 768:	learn: 0.0590416	total: 1m 4s	remaining: 19.3s
# 769:	learn: 0.0589096	total: 1m 4s	remaining: 19.2s
# 770:	learn: 0.0588497	total: 1m 4s	remaining: 19.1s
# 771:	learn: 0.0587270	total: 1m 4s	remaining: 19.1s
# 772:	learn: 0.0586109	total: 1m 4s	remaining: 19s
# 773:	learn: 0.0584843	total: 1m 4s	remaining: 18.9s
# 774:	learn: 0.0583549	total: 1m 4s	remaining: 18.8s
# 775:	learn: 0.0582287	total: 1m 4s	remaining: 18.7s
# 776:	learn: 0.0581175	total: 1m 5s	remaining: 18.7s
# 777:	learn: 0.0580083	total: 1m 5s	remaining: 18.6s
# 778:	learn: 0.0579642	total: 1m 5s	remaining: 18.5s
# 779:	learn: 0.0577927	total: 1m 5s	remaining: 18.4s
# 780:	learn: 0.0576860	total: 1m 5s	remaining: 18.4s
# 781:	learn: 0.0575595	total: 1m 5s	remaining: 18.3s
# 782:	learn: 0.0574679	total: 1m 5s	remaining: 18.2s
# 783:	learn: 0.0573600	total: 1m 5s	remaining: 18.1s
# 784:	learn: 0.0572654	total: 1m 5s	remaining: 18.1s
# 785:	learn: 0.0571846	total: 1m 6s	remaining: 18s
# 786:	learn: 0.0571036	total: 1m 6s	remaining: 17.9s
# 787:	learn: 0.0569594	total: 1m 6s	remaining: 17.8s
# 788:	learn: 0.0568587	total: 1m 6s	remaining: 17.7s
# 789:	learn: 0.0567664	total: 1m 6s	remaining: 17.7s
# 790:	learn: 0.0566889	total: 1m 6s	remaining: 17.6s
# 791:	learn: 0.0565738	total: 1m 6s	remaining: 17.5s
# 792:	learn: 0.0563907	total: 1m 6s	remaining: 17.4s
# 793:	learn: 0.0562923	total: 1m 6s	remaining: 17.3s
# 794:	learn: 0.0562031	total: 1m 6s	remaining: 17.2s
# 795:	learn: 0.0561027	total: 1m 6s	remaining: 17.1s
# 796:	learn: 0.0560110	total: 1m 6s	remaining: 17s
# 797:	learn: 0.0558706	total: 1m 6s	remaining: 17s
# 798:	learn: 0.0557948	total: 1m 7s	remaining: 16.9s
# 799:	learn: 0.0557172	total: 1m 7s	remaining: 16.8s
# 800:	learn: 0.0556218	total: 1m 7s	remaining: 16.7s
# 801:	learn: 0.0554715	total: 1m 7s	remaining: 16.6s
# 802:	learn: 0.0553761	total: 1m 7s	remaining: 16.5s
# 803:	learn: 0.0552444	total: 1m 7s	remaining: 16.4s
# 804:	learn: 0.0551586	total: 1m 7s	remaining: 16.3s
# 805:	learn: 0.0550853	total: 1m 7s	remaining: 16.2s
# 806:	learn: 0.0549990	total: 1m 7s	remaining: 16.2s
# 807:	learn: 0.0549015	total: 1m 7s	remaining: 16.1s
# 808:	learn: 0.0547956	total: 1m 7s	remaining: 16s
# 809:	learn: 0.0546622	total: 1m 7s	remaining: 15.9s
# 810:	learn: 0.0545584	total: 1m 7s	remaining: 15.8s
# 811:	learn: 0.0544631	total: 1m 7s	remaining: 15.7s
# 812:	learn: 0.0543798	total: 1m 7s	remaining: 15.6s
# 813:	learn: 0.0542440	total: 1m 7s	remaining: 15.5s
# 814:	learn: 0.0541297	total: 1m 8s	remaining: 15.4s
# 815:	learn: 0.0540171	total: 1m 8s	remaining: 15.4s
# 816:	learn: 0.0539283	total: 1m 8s	remaining: 15.3s
# 817:	learn: 0.0538380	total: 1m 8s	remaining: 15.2s
# 818:	learn: 0.0537214	total: 1m 8s	remaining: 15.1s
# 819:	learn: 0.0536240	total: 1m 8s	remaining: 15s
# 820:	learn: 0.0534917	total: 1m 8s	remaining: 14.9s
# 821:	learn: 0.0534058	total: 1m 8s	remaining: 14.8s
# 822:	learn: 0.0533322	total: 1m 8s	remaining: 14.7s
# 823:	learn: 0.0532182	total: 1m 8s	remaining: 14.7s
# 824:	learn: 0.0531058	total: 1m 8s	remaining: 14.6s
# 825:	learn: 0.0530311	total: 1m 8s	remaining: 14.5s
# 853:	learn: 0.0008091	total: 10m 44s	remaining: 1m 50s
# 854:	learn: 0.0008078	total: 10m 45s	remaining: 1m 49s
# 855:	learn: 0.0008069	total: 10m 46s	remaining: 1m 48s
# 856:	learn: 0.0008058	total: 10m 47s	remaining: 1m 48s
# 857:	learn: 0.0008045	total: 10m 47s	remaining: 1m 47s
# 858:	learn: 0.0008020	total: 10m 48s	remaining: 1m 46s
# 859:	learn: 0.0008008	total: 10m 49s	remaining: 1m 45s
# 860:	learn: 0.0008003	total: 10m 49s	remaining: 1m 44s
# 861:	learn: 0.0007986	total: 10m 50s	remaining: 1m 44s
# 862:	learn: 0.0007972	total: 10m 51s	remaining: 1m 43s
# 863:	learn: 0.0007967	total: 10m 51s	remaining: 1m 42s
# 864:	learn: 0.0007958	total: 10m 52s	remaining: 1m 41s
# 865:	learn: 0.0007914	total: 10m 53s	remaining: 1m 41s
# 866:	learn: 0.0007909	total: 10m 53s	remaining: 1m 40s
# 867:	learn: 0.0007897	total: 10m 54s	remaining: 1m 39s
# 868:	learn: 0.0007887	total: 10m 54s	remaining: 1m 38s
# 869:	learn: 0.0007884	total: 10m 55s	remaining: 1m 37s
# 870:	learn: 0.0007864	total: 10m 56s	remaining: 1m 37s
# 871:	learn: 0.0007854	total: 10m 57s	remaining: 1m 36s
# 872:	learn: 0.0007827	total: 10m 58s	remaining: 1m 35s
# 873:	learn: 0.0007816	total: 10m 59s	remaining: 1m 35s
# 874:	learn: 0.0007800	total: 11m	remaining: 1m 34s
# 875:	learn: 0.0007792	total: 11m 1s	remaining: 1m 33s
# 876:	learn: 0.0007783	total: 11m 2s	remaining: 1m 32s
# 877:	learn: 0.0007769	total: 11m 3s	remaining: 1m 32s
# 878:	learn: 0.0007764	total: 11m 3s	remaining: 1m 31s
# 879:	learn: 0.0007748	total: 11m 4s	remaining: 1m 30s
# 880:	learn: 0.0007699	total: 11m 4s	remaining: 1m 29s
# 881:	learn: 0.0007688	total: 11m 5s	remaining: 1m 29s
# 882:	learn: 0.0007678	total: 11m 6s	remaining: 1m 28s
# 883:	learn: 0.0007671	total: 11m 6s	remaining: 1m 27s
# 884:	learn: 0.0007660	total: 11m 7s	remaining: 1m 26s
# 885:	learn: 0.0007656	total: 11m 8s	remaining: 1m 25s
# 886:	learn: 0.0007647	total: 11m 8s	remaining: 1m 25s
# 887:	learn: 0.0007643	total: 11m 9s	remaining: 1m 24s
# 888:	learn: 0.0007630	total: 11m 10s	remaining: 1m 23s
# 889:	learn: 0.0007625	total: 11m 10s	remaining: 1m 22s
# 890:	learn: 0.0007619	total: 11m 11s	remaining: 1m 22s
# 891:	learn: 0.0007600	total: 11m 11s	remaining: 1m 21s
# 892:	learn: 0.0007593	total: 11m 12s	remaining: 1m 20s
# 893:	learn: 0.0007585	total: 11m 14s	remaining: 1m 19s
# 894:	learn: 0.0007578	total: 11m 15s	remaining: 1m 19s
# 895:	learn: 0.0007554	total: 11m 16s	remaining: 1m 18s
# 896:	learn: 0.0007531	total: 11m 17s	remaining: 1m 17s
# 988:	learn: 0.0006611	total: 12m 25s	remaining: 8.29s
# 989:	learn: 0.0006603	total: 12m 25s	remaining: 7.53s
# 990:	learn: 0.0006602	total: 12m 26s	remaining: 6.78s
# 991:	learn: 0.0006594	total: 12m 26s	remaining: 6.02s
# 992:	learn: 0.0006584	total: 12m 27s	remaining: 5.27s
# 993:	learn: 0.0006565	total: 12m 28s	remaining: 4.52s
# 994:	learn: 0.0006555	total: 12m 29s	remaining: 3.76s
# 995:	learn: 0.0006547	total: 12m 30s	remaining: 3.01s
# 996:	learn: 0.0006541	total: 12m 31s	remaining: 2.26s
# 997:	learn: 0.0006534	total: 12m 32s	remaining: 1.51s
# 998:	learn: 0.0006517	total: 12m 33s	remaining: 754ms
# 999:	learn: 0.0006511	total: 12m 34s	remaining: 0us
# Syn:  {'Random_Forest': 0.8699278846153848, 'Logistic_Regression': 0.7190064102564103, 'Naive_Bayes': 0.7046474358974358, 'CatBoost': 0.8458814102564104}
# Model:  XGBoost
# Real:  {'Random_Forest': 0.9431650641025642, 'Logistic_Regression': 0.7774358974358975, 'Naive_Bayes': 0.7818910256410256, 'CatBoost': 0.9669070512820513, 'XGBoost': 0.9657532051282052}
# Syn:  {'Random_Forest': 0.8699278846153848, 'Logistic_Regression': 0.7190064102564103, 'Naive_Bayes': 0.7046474358974358, 'CatBoost': 0.8458814102564104, 'XGBoost': 0.8417788461538461}

# %%
real_scores
# Out:
# {'Random_Forest': 0.9431650641025642,
#  'Logistic_Regression': 0.7774358974358975,
#  'Naive_Bayes': 0.7818910256410256,
#  'CatBoost': 0.9669070512820513,
#  'XGBoost': 0.9657532051282052}

# %%
synth_scores
# Out:
# {'Random_Forest': 0.8699278846153848,
#  'Logistic_Regression': 0.7190064102564103,
#  'Naive_Bayes': 0.7046474358974358,
#  'CatBoost': 0.8458814102564104,
#  'XGBoost': 0.8417788461538461}

# %%
real_ranking
# Out:
# ['CatBoost', 'XGBoost', 'Random_Forest', 'Naive_Bayes', 'Logistic_Regression']

# %%
synth_ranking
# Out:
# ['Random_Forest', 'CatBoost', 'XGBoost', 'Logistic_Regression', 'Naive_Bayes']

# %%
from scipy.stats import spearmanr

# 성능 지표를 데이터프레임으로 변환
real_df = pd.DataFrame(list(real_scores.items()), columns=['Model', 'Real_Score'])
synth_df = pd.DataFrame(list(synth_scores.items()), columns=['Model', 'Synth_Score'])

# 성능 지표 순위화
real_df['Real_Rank'] = real_df['Real_Score'].rank(ascending=False)
synth_df['Synth_Rank'] = synth_df['Synth_Score'].rank(ascending=False)

# 데이터프레임 병합 (모델 이름을 기준으로)
merged_df = pd.merge(real_df, synth_df, on='Model')

# 스피어만 순위 상관관계 계산
spearman_corr, _ = spearmanr(merged_df['Real_Rank'], merged_df['Synth_Rank'])

# 결과 출력
print(f"Spearman Rank Correlation: {spearman_corr:.4f}")
# Out:
# Spearman Rank Correlation: 0.6000

# %% [markdown]
# # Classification Performance

# %%
# 성능 차이 계산
score_differences = {model: real_scores[model] - synth_scores[model] for model in real_scores}

add = 0
# 결과 출력
for model, difference in score_differences.items():
    add += abs(difference)
    print(f"{model} difference: {difference:.6f}")
print()
print("평균: ", round(add / 5, 5))
# Out:
# Random_Forest difference: 0.073237
# Logistic_Regression difference: 0.058429
# Naive_Bayes difference: 0.077244
# CatBoost difference: 0.121026
# XGBoost difference: 0.123974
#
# 평균:  0.09078

# %% [markdown]
# # Feature extraction

# %%
import xgboost as xgb
import pandas as pd
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

# 실제 데이터셋으로 XGBoost 모델 학습
model_real = models_out['XGBoost']['real_model']

# 합성 데이터셋으로 XGBoost 모델 학습
model_synthetic = models_out['XGBoost']['syn_model']

# 실제 데이터셋에서의 피처 중요도
importance_real = model_real.get_booster().get_score(importance_type='weight')
importance_real_df = pd.DataFrame(list(importance_real.items()), columns=['Feature', 'Importance_Real'])

# 합성 데이터셋에서의 피처 중요도
importance_synthetic = model_synthetic.get_booster().get_score(importance_type='weight')
importance_synthetic_df = pd.DataFrame(list(importance_synthetic.items()), columns=['Feature', 'Importance_Synthetic'])

# 피처 중요도를 순위화
importance_real_df['Rank_Real'] = importance_real_df['Importance_Real'].rank(ascending=False)
importance_synthetic_df['Rank_Synthetic'] = importance_synthetic_df['Importance_Synthetic'].rank(ascending=False)

# 두 데이터프레임 병합 (모든 피처가 동일해야 함)
merged_df = pd.merge(importance_real_df, importance_synthetic_df, on='Feature', how='inner')

# 스피어만 순위 상관관계 계산
spearman_corr, _ = spearmanr(merged_df['Rank_Real'], merged_df['Rank_Synthetic'])
print(f"Spearman Rank Correlation: {spearman_corr:.4f}")

# 피처 중요도 비교 시각화
plt.figure(figsize=(10, 8))
plt.scatter(merged_df['Rank_Real'], merged_df['Rank_Synthetic'])
plt.title('Feature Importance Rank Comparison')
plt.xlabel('Rank in Real Data')
plt.ylabel('Rank in Synthetic Data')
plt.grid(True)
plt.show()
# Out:
# Spearman Rank Correlation: 0.6781

# %% [markdown]
# # 익명성 평가

# %%
import numpy as np
import pandas as pd

# 실제 데이터 (Original Data)와 합성 데이터 (Synthetic Data)를 불러옵니다.
df_real = subset  # 원본 데이터
df_synth = syn_subset  # 합성 데이터

# 평가에 사용할 칼럼들
key_columns = ['Customer_Birthyear', 'Customer_Gender', 'Customer_credit_rating', 'Customer_identification_number', 'Location','IP_Address','MAC_Address', 'Customer_personal_identifier',
               'Transaction_Datetime', 'Account_account_number']
target_column = 'Fraud_Type'

# TCAP 계산 함수 정의
def calculate_tcap(df_real, df_synth, key_columns, target_column):
    n = len(df_real)
    numerator = 0
    denominator = 0

    for i in range(n):
        real_key = tuple(df_real[key_columns].iloc[i].values)
        synth_key = tuple(df_synth[key_columns].iloc[i].values)

        if real_key == synth_key:
            denominator += 1
            if df_real[target_column].iloc[i] == df_synth[target_column].iloc[i]:
                numerator += 1

    tcap_value = numerator / denominator if denominator != 0 else 0
    return tcap_value

# TCAP 계산
tcap_value = calculate_tcap(df_real, df_synth, key_columns, target_column)
print(f"TCAP Value: {tcap_value:.4f}")
# Out:
# TCAP Value: 0.0000
