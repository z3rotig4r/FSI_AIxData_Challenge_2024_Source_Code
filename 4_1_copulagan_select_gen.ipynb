# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 제출 파일 생성 관련
import os
import zipfile

# 데이터 처리 및 분석
import pandas as pd
import numpy as np
from scipy import stats
from tqdm import tqdm

# To ignore all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 불러오기
path = '/content/drive/MyDrive/Colab Notebooks/fsi/open/'
save_path = '/content/drive/MyDrive/Colab Notebooks/fsi/processed_data/1_all_pre_syn.csv'

train_all = pd.read_csv(path + "train.csv")
test_all = pd.read_csv(path + "test.csv")
saved_train = pd.read_csv(save_path)

save_path = '/content/drive/MyDrive/Colab Notebooks/fsi/processed_data'
all_synthetic_data = pd.read_csv(save_path + '/copulagan_syn_data.csv')

train = train_all.drop(columns="ID")
saved_train["Fraud_Type"].value_counts()
# Out:
# Fraud_Type
# m    118800
# a       100
# j       100
# h       100
# k       100
# c       100
# g       100
# i       100
# b       100
# f       100
# d       100
# e       100
# l       100
# Name: count, dtype: int64

# %%
# 설치
# !pip install sdmetrics

# %%
# !pip install sdv

# %%
# !pip install catboost

# %% [markdown]
# # 통계적 관점

# %%
from sdv.metadata import SingleTableMetadata

# 메타 데이터 타입 설정
column_sdtypes = {
        'Account_amount_daily_limit': 'numerical',
        'Transaction_num_connection_failure': 'numerical',
        'Number_of_transaction_with_the_account': 'numerical',
        'Transaction_history_with_the_account': 'numerical',
        'Account_initial_balance': 'numerical',
        'Account_balance': 'numerical',
        'Customer_identification_number': 'categorical',
        'Customer_personal_identifier': 'categorical',
        'Account_account_number': 'categorical',
        'IP_Address': 'ipv4_address',
        'Location': 'categorical',
        'Recipient_Account_Number': 'categorical',
        'Fraud_Type': 'categorical',
        'Customer_Birthyear': 'numerical'
    }

fraud_type = 'a'
subset = saved_train[saved_train["Fraud_Type"] == fraud_type]
syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == fraud_type]
subset = subset.drop('Time_difference_seconds', axis=1)

# 메타데이터 생성 및 모델 학습
metadata = SingleTableMetadata()

metadata.detect_from_dataframe(subset)
metadata.set_primary_key(None)

# 각 컬럼에 대해 데이터 타입 설정
for column, sdtype in column_sdtypes.items():
    metadata.update_column(
        column_name=column,
        sdtype=sdtype
    )

# %%
from sdmetrics.reports.single_table import DiagnosticReport
from sdmetrics.reports.single_table import QualityReport

types = saved_train.Fraud_Type.unique()
statis = pd.DataFrame(types, columns=['Fraud_Type'])
statis['Data_Quality'] = 0
statis['Data_Diagnostic'] = 0
statis['Conti_statis'] = 0
statis['Cate_statis'] = 0

for x in types:
    if x == 'm':
        continue
    subset = saved_train[saved_train["Fraud_Type"] == x]
    syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == x]
    subset = subset.drop('Time_difference_seconds', axis=1)

    # 메타데이터 생성 및 모델 학습
    metadata = SingleTableMetadata()
    metadata.detect_from_dataframe(subset)
    metadata.set_primary_key(None)

    # 각 컬럼에 대해 데이터 타입 설정
    for column, sdtype in column_sdtypes.items():
        metadata.update_column(
            column_name=column,
            sdtype=sdtype)

    report_q = QualityReport()
    report_d = DiagnosticReport()

    metadata_as_dict = metadata.to_dict()
    report_q.generate(subset, syn_subset, metadata_as_dict)
    report_d.generate(subset, syn_subset, metadata_as_dict)

    statis.loc[statis['Fraud_Type'] == x, 'Data_Quality'] = report_q.get_score()
    statis.loc[statis['Fraud_Type'] == x, 'Data_Diagnostic'] = report_d.get_score()
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:02<00:00, 24.45it/s]|
# Column Shapes Score: 71.2%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [06:17<00:00,  5.18it/s]|
# Column Pair Trends Score: 56.86%
#
# Overall Score (Average): 64.03%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1271.87it/s]|
# Data Validity Score: 98.41%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 157.38it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.2%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 121.52it/s]|
# Column Shapes Score: 75.49%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [03:31<00:00,  9.21it/s]|
# Column Pair Trends Score: 61.97%
#
# Overall Score (Average): 68.73%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 854.28it/s]|
# Data Validity Score: 97.83%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 224.84it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 98.92%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 199.41it/s]|
# Column Shapes Score: 73.64%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.26it/s]|
# Column Pair Trends Score: 59.36%
#
# Overall Score (Average): 66.5%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1279.27it/s]|
# Data Validity Score: 99.3%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 227.26it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.65%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:02<00:00, 30.96it/s]|
# Column Shapes Score: 69.24%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [08:27<00:00,  3.85it/s]|
# Column Pair Trends Score: 54.99%
#
# Overall Score (Average): 62.11%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1225.50it/s]|
# Data Validity Score: 98.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 281.33it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 291.71it/s]|
# Column Shapes Score: 73.95%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.31it/s]|
# Column Pair Trends Score: 60.92%
#
# Overall Score (Average): 67.43%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 863.56it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 155.58it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 223.50it/s]|
# Column Shapes Score: 71.78%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:53<00:00, 17.23it/s]|
# Column Pair Trends Score: 59.48%
#
# Overall Score (Average): 65.63%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 697.20it/s]|
# Data Validity Score: 99.48%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 184.37it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.74%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 87.83it/s]|
# Column Shapes Score: 77.05%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [03:10<00:00, 10.25it/s]|
# Column Pair Trends Score: 64.47%
#
# Overall Score (Average): 70.76%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 754.34it/s]|
# Data Validity Score: 98.92%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 181.74it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.46%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 174.97it/s]|
# Column Shapes Score: 73.02%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:05<00:00, 29.81it/s]|
# Column Pair Trends Score: 60.95%
#
# Overall Score (Average): 66.98%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1183.02it/s]|
# Data Validity Score: 99.97%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 290.79it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.99%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 273.51it/s]|
# Column Shapes Score: 77.33%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:03<00:00, 30.53it/s]|
# Column Pair Trends Score: 62.92%
#
# Overall Score (Average): 70.12%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 677.87it/s]|
# Data Validity Score: 99.96%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 273.03it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.98%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 177.28it/s]|
# Column Shapes Score: 74.42%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.41it/s]|
# Column Pair Trends Score: 60.41%
#
# Overall Score (Average): 67.42%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1253.78it/s]|
# Data Validity Score: 99.82%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 226.36it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.91%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 275.29it/s]|
# Column Shapes Score: 75.95%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.40it/s]|
# Column Pair Trends Score: 61.5%
#
# Overall Score (Average): 68.72%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1291.70it/s]|
# Data Validity Score: 99.99%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 149.07it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 63/63 [00:00<00:00, 295.74it/s]|
# Column Shapes Score: 73.53%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1953/1953 [01:04<00:00, 30.22it/s]|
# Column Pair Trends Score: 59.42%
#
# Overall Score (Average): 66.48%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 63/63 [00:00<00:00, 1099.43it/s]|
# Data Validity Score: 99.84%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 218.78it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.92%

# %%
statis
# Out:
#    Fraud_Type  Data_Quality  Data_Diagnostic  Conti_statis  Cate_statis
# 0           m      0.000000         0.000000             0            0
# 1           a      0.640295         0.992049             0            0
# 2           j      0.687274         0.989172             0            0
# 3           h      0.664995         0.996475             0            0
# 4           k      0.621138         0.990007             0            0
# 5           c      0.674333         1.000000             0            0
# 6           g      0.656299         0.997421             0            0
# 7           i      0.707600         0.994577             0            0
# 8           b      0.669836         0.999868             0            0
# 9           f      0.701238         0.999795             0            0
# 10          d      0.674163         0.999092             0            0
# 11          e      0.687229         0.999954             0            0
# 12          l      0.664792         0.999176             0            0

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sdmetrics.visualization import get_column_plot

# 시간 차이 계산
subset['Time_difference_seconds'] = pd.to_timedelta(subset['Time_difference']).dt.total_seconds()
syn_subset['Time_difference_seconds'] = pd.to_timedelta(syn_subset['Time_difference']).dt.total_seconds()

# 그래프에 추가할 컬럼 목록
columns = ['Transaction_Amount', 'Account_initial_balance', 'Account_balance',
           'Account_one_month_max_amount',
           'Account_one_month_std_dev', 'Account_dawn_one_month_max_amount',
           'Time_difference_seconds', 'Account_dawn_one_month_std_dev']

# 3x3 서브플롯 생성
fig = make_subplots(rows=3, cols=3, subplot_titles=columns)

# 각 컬럼에 대해 그래프 생성 및 서브플롯에 추가
for i, col in enumerate(columns):
    row = i // 3 + 1
    col_idx = i % 3 + 1

    # 각 컬럼에 대한 plotly figure 생성
    fig_ = get_column_plot(
        real_data=subset,
        synthetic_data=syn_subset,
        column_name=col,
        plot_type='distplot'
    )

    # 서브플롯에 그래프 추가
    for trace in fig_.data:
        fig.add_trace(trace, row=row, col=col_idx)

# 레이아웃 조정
fig.update_layout(
    height=900,
    width=1200,  # 가로 길이를 늘림
    title_text= x + ": Comparison of Distributions",
    title_font=dict(size=14)  # 제목 글씨 크기 조정
)

# 인터랙티브한 플롯 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.0.min.js"></script>                <div id="06ed670d-4ece-41cd-8274-81841449649c" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06ed670d-4ece-41cd-8274-81841449649c")) {                    Plotly.newPlot(                        "06ed670d-4ece-41cd-8274-81841449649c",                        [{"fill":"tozeroy","hovertemplate":"\u003cb\u003eReal\u003c\u002fb\u003e\u003cbr\u003eFrequency: %{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Real","marker":{"color":"#000036"},"mode":"lines","name":"Real","showlegend":true,"x":[-25200000.0,-25149640.0,-25099280.0,-25048920.0,-24998560.0,-24948200.0,-24897840.0,-24847480.0,-24797120.0,-24746760.0,-24696400.0,-24646040.0,-24595680.0,-24545320.0,-24494960.0,-24444600.0,-24394240.0,-24343880.0,-24293520.0,-24243160.0,-24192800.0,-24142440.0,-24092080.0,-24041720.0,-23991360.0,-23941000.0,-23890640.0,-23840280.0,-23789920.0,-23739560.0,-23689200.0,-23638840.0,-23588480.0,-23538120.0,-23487760.0,-23437400.0,-23387040.0,-23336680.0,-23286320.0,-23235960.0,-23185600.0,-23135240.0,-23084880.0,-23034520.0,-22984160.0,-22933800.0,-22883440.0,-22833080.0,-22782720.0,-22732360.0,-22682000.0,-22631640.0,-22581280.0,-22530920.0,-22480560.0,-22430200.0,-22379840.0,-22329480.0,-22279120.0,-22228760.0,-22
    kld_pq = entropy(p, q)
    kld_qp = entropy(q, p)

    inv_kld = 0.5 * (kld_pq + kld_qp)

    return inv_kld

from scipy.spatial.distance import jensenshannon

def calculate_jsd(p, q, base=np.e, epsilon=1e-10):
    """
    두 확률 분포 p와 q 사이의 Jensen-Shannon Divergence를 계산합니다.
    p와 q는 각 요소가 대응되는 동일한 길이의 확률 분포여야 합니다.
    NaN을 방지하기 위해 epsilon 값을 추가하여 안정화합니다.
    """
    # 작은 값을 더해줌으로써 NaN 방지
    p = np.asarray(p, dtype=np.float64) + epsilon
    q = np.asarray(q, dtype=np.float64) + epsilon

    # 두 분포를 다시 확률 분포로 정상화 (합이 1이 되도록)
    p /= p.sum()
    q /= q.sum()

    # Jensen-Shannon Divergence 계산
    jsd = jensenshannon(p, q, base=base) ** 2  # 결과는 sqrt(JSD)로 반환되므로 제곱하여 JSD로 변환
    return jsd


# 그래프에 추가할 컬럼 목록
columns = ['Transaction_Amount', 'Account_initial_balance', 'Account_balance',
           'Account_remaining_amount_daily_limit_exceeded', 'Account_one_month_max_amount',
           'Account_one_month_std_dev', 'Account_dawn_one_month_max_amount',
           'Time_difference_seconds', 'Account_dawn_one_month_std_dev']

for x in types:
    col_score = 0
    col_cnt = 0
    print(x)
    subset = saved_train[saved_train["Fraud_Type"] == x]
    syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == x]

    subset['Time_difference_seconds'] = pd.to_timedelta(subset['Time_difference']).dt.total_seconds()
    syn_subset['Time_difference_seconds'] = pd.to_timedelta(syn_subset['Time_difference']).dt.total_seconds()

    for col in columns:
        # 연속형 변수 예시
        real_data = subset[col].values
        synth_data = syn_subset[col].values

        # 두 데이터셋의 최소, 최대 범위 설정
        data_min = min(real_data.min(), synth_data.min())
        data_max = max(real_data.max(), synth_data.max())

        # 히스토그램으로 나눌 bins 설정
        bins = np.linspace(data_min, data_max, 20)

        # 각 bins에 대한 확률 밀도 계산
        real_hist, _ = np.histogram(real_data, bins=bins, density=True)
        synth_hist, _ = np.histogram(synth_data, bins=bins, density=True)

        # Inverse KLD / JSD 계산
        result = calculate_jsd(real_hist, synth_hist)
        if np.isnan(result):
            continue
        col_score += result
        col_cnt += 1
        print(col, result)

    # 1일수록 두 분포 차이가 있음. 0은 완전 동일.
    statis.loc[statis['Fraud_Type'] == x, 'Conti_statis'] = col_score / col_cnt
    print("------------------")
# Out:
# m
# Transaction_Amount 0.6029494945056523
# Account_initial_balance 0.22283031124934763
# Account_balance 0.18283818577387811
# Account_remaining_amount_daily_limit_exceeded 0.12145610985638765
# Account_one_month_max_amount 0.07485138345223621
# Account_one_month_std_dev 0.07631070667125608
# Account_dawn_one_month_max_amount 0.06046613676037318
# Time_difference_seconds 2.2375767575891024e-06
# Account_dawn_one_month_std_dev 0.05872868211105883
# ------------------
# a
# Transaction_Amount 0.3016787463288506
# Account_initial_balance 0.1622785735126906
# Account_balance 0.14139409905796912
# Account_remaining_amount_daily_limit_exceeded 0.3956044093903424
# Account_one_month_max_amount 0.15328300321085458
# Account_one_month_std_dev 0.11663236225426826
# Account_dawn_one_month_max_amount 0.0380480356925231
# Time_difference_seconds 0.00402278283714032
# Account_dawn_one_month_std_dev 0.06142675142332406
# ------------------
# j
# Transaction_Amount 0.3553589548595448
# Account_initial_balance 0.12317407420426227
# Account_balance 0.08934409163219142
# Account_remaining_amount_daily_limit_exceeded 0.2002955021681762
# Account_one_month_max_amount 0.140569313971831
# Account_one_month_std_dev 0.09233111381058824
# Account_dawn_one_month_max_amount 0.0674976964245138
# Time_difference_seconds 0.013593886154205764
# Account_dawn_one_month_std_dev 0.06758572820923442
# ------------------
# h
# Transaction_Amount 0.20416671832686828
# Account_initial_balance 0.10031084288555986
# Account_balance 0.18926831038966524
# Account_remaining_amount_daily_limit_exceeded 0.13657366294610768
# Account_one_month_max_amount 0.09330809031602146
# Time_difference_seconds 0.08635021542624043
# ------------------
# k
# Transaction_Amount 0.36704477719537354
# Account_initial_balance 0.1605654612159314
# Account_balance 0.1561216784917014
# Account_remaining_amount_daily_limit_exceeded 0.41761431728438336
# Account_one_month_max_amount 0.10300101425554081
# Account_one_month_std_dev 0.22851220046276194
# Account_dawn_one_month_max_amount 0.07778392779338669
# Time_difference_seconds 0.04727651008420366
# Account_dawn_one_month_std_dev 0.08456255253025823
# ------------------
# c
# Transaction_Amount 0.2920270646311093
# Account_initial_balance 0.12662320770558022
# Account_balance 0.10256014518286043
# Account_remaining_amount_daily_limit_exceeded 0.1087277930815469
# Account_one_month_max_amount 0.1562673694582123
# Account_one_month_std_dev 0.12385527893538646
# Account_dawn_one_month_max_amount 0.09394843428162367
# Time_difference_seconds 0.010073819060192344
# Account_dawn_one_month_std_dev 0.09430914721212198
# ------------------
# g
# Transaction_Amount 0.33041829306234505
# Account_initial_balance 0.1540052846752303
# Account_balance 0.238905852733937
# Account_remaining_amount_daily_limit_exceeded 0.03751091921988183
# Account_one_month_max_amount 0.1622532840368779
# Account_one_month_std_dev 0.16432578662052344
# Account_dawn_one_month_max_amount 0.07644046800777676
# Time_difference_seconds 0.21115941650978567
# Account_dawn_one_month_std_dev 0.06594780921796048
# ------------------
# i
# Transaction_Amount 0.2361033224969061
# Account_initial_balance 0.09167363832513242
# Account_balance 0.20179780609503312
# Account_remaining_amount_daily_limit_exceeded 0.1428776581783016
# Account_one_month_max_amount 0.21474852156871227
# Account_one_month_std_dev 0.07505976161823308
# Account_dawn_one_month_max_amount 0.1715173275302041
# Time_difference_seconds 0.11115553330582027
# Account_dawn_one_month_std_dev 0.1571607481541281
# ------------------
# b
# Transaction_Amount 0.22303259567956935
# Account_initial_balance 0.1920738960331024
# Account_balance 0.16476085149888586
# Account_one_month_max_amount 0.09807743153252832
# Account_one_month_std_dev 0.11012560841809711
# Account_dawn_one_month_max_amount 0.09064316226393535
# Time_difference_seconds 0.02434110596944517
# Account_dawn_one_month_std_dev 0.09044693125599286
# ------------------
# f
# Transaction_Amount 0.21522150288685507
# Account_initial_balance 0.0741795815397344
# Account_balance 0.3299694747271276
# Account_remaining_amount_daily_limit_exceeded 0.21994679439779546
# Account_one_month_max_amount 0.11350368402654913
# Account_one_month_std_dev 0.13935712312170498
# Time_difference_seconds 0.08928139559359709
# ------------------
# d
# Transaction_Amount 0.34725238802827285
# Account_initial_balance 0.10097738511056409
# Account_balance 0.07144429077945352
# Account_remaining_amount_daily_limit_exceeded 0.126462511905449
# Account_one_month_max_amount 0.17117149388672812
# Account_one_month_std_dev 0.163719374721717
# Account_dawn_one_month_max_amount 0.15294957530591044
# Time_difference_seconds 0.01714653041523491
# Account_dawn_one_month_std_dev 0.11956830910620656
# ------------------
# e
# Transaction_Amount 0.37942212950545756
# Account_initial_balance 0.12985646119799754
# Account_balance 0.11593394369120072
# Account_remaining_amount_daily_limit_exceeded 0.386451443133672
# Account_one_month_max_amount 0.08384461377396872
# Account_one_month_std_dev 0.13037085506030474
# Time_difference_seconds 0.10021963570720295
# ------------------
# l
# Transaction_Amount 0.31645241936919677
# Account_initial_balance 0.13150182941115043
# Account_balance 0.10154688476324268
# Account_one_month_max_amount 0.09232476431188294
# Account_one_month_std_dev 0.21365161779785843
# Account_dawn_one_month_max_amount 0.0681686145184709
# Time_difference_seconds 0.07949819365902265
# Account_dawn_one_month_std_dev 0.08408073954680699
# ------------------

# %%
statis
# Out:
#    Fraud_Type  Data_Quality  Data_Diagnostic  Conti_statis  Cate_statis
# 0           m      0.000000         0.000000      0.155604            0
# 1           a      0.640295         0.992049      0.152708            0
# 2           j      0.687274         0.989172      0.127750            0
# 3           h      0.664995         0.996475      0.134996            0
# 4           k      0.621138         0.990007      0.182498            0
# 5           c      0.674333         1.000000      0.123155            0
# 6           g      0.656299         0.997421      0.160107            0
# 7           i      0.707600         0.994577      0.155788            0
# 8           b      0.669836         0.999868      0.124188            0
# 9           f      0.701238         0.999795      0.168780            0
# 10          d      0.674163         0.999092      0.141188            0
# 11          e      0.687229         0.999954      0.189443            0
# 12          l      0.664792         0.999176      0.135903            0

# %%
from scipy.spatial.distance import jensenshannon

# 실제 데이터셋과 합성 데이터셋
cate_cols = ['Customer_Gender', 'Customer_personal_identifier', 'Customer_identification_number', 'Customer_credit_rating',
             'Customer_loan_type', 'Account_account_number', 'Account_account_type', 'Channel', 'Operating_System', 'Error_Code',
             'Type_General_Automatic', 'IP_Address', 'MAC_Address', 'Access_Medium', 'Location', 'Recipient_Account_Number',
             ]

binary_cols = ['Customer_flag_change_of_authentication_1', 'Customer_flag_change_of_authentication_2', 'Customer_flag_change_of_authentication_3',
               'Customer_flag_change_of_authentication_4','Customer_rooting_jailbreak_indicator', 'Customer_mobile_roaming_indicator', 'Customer_VPN_Indicator',
               'Customer_flag_terminal_malicious_behavior_1', 'Customer_flag_terminal_malicious_behavior_2', 'Customer_flag_terminal_malicious_behavior_3',
               'Customer_flag_terminal_malicious_behavior_4', 'Customer_flag_terminal_malicious_behavior_5', 'Customer_flag_terminal_malicious_behavior_6',
               'Customer_inquery_atm_limit', 'Customer_increase_atm_limit', 'Account_indicator_release_limit_excess', 'Account_indicator_Openbanking',
               'Account_release_suspention', 'Transaction_Failure_Status', 'Another_Person_Account', 'Unused_terminal_status', 'First_time_iOS_by_vulnerable_user',
               'Flag_deposit_more_than_tenMillion', 'Unused_account_status', 'Recipient_account_suspend_status'
               ]

# 그래프에 추가할 컬럼 목록
columns = cate_cols + binary_cols

for x in types:
    col_score = 0
    col_cnt = 0
    print(x)
    subset = saved_train[saved_train["Fraud_Type"] == x]
    syn_subset = all_synthetic_data[all_synthetic_data["Fraud_Type"] == x]

    for col in columns:
        # 연속형 변수 예시
        real_data = subset[col]
        synth_data = syn_subset[col]

        # 두 데이터셋의 카테고리별 빈도 계산
        real_counts = real_data.value_counts(normalize=True)
        synth_counts = synth_data.value_counts(normalize=True)

        # 빈도 테이블을 맞추기 위해 누락된 카테고리를 0으로 채움
        all_categories = real_counts.index.union(synth_counts.index)
        real_counts = real_counts.reindex(all_categories, fill_value=0)
        synth_counts = synth_counts.reindex(all_categories, fill_value=0)

        # JSD 계산
        result = jensenshannon(real_counts, synth_counts) ** 2  # JSD 계산

        col_score += result
        col_cnt += 1
        print(col, result)

    # 1일수록 두 분포 차이가 있음. 0은 완전 동일.
    statis.loc[statis['Fraud_Type'] == x, 'Cate_statis'] = col_score / col_cnt
    print("------------------")
# Out:
# m
# Customer_Gender 0.0430345738754083
# Customer_personal_identifier 0.627110335597788
# Customer_identification_number 0.6705945366956139
# Customer_credit_rating 0.053191679561475295
# Customer_loan_type 0.010501351377252378
# Account_account_number 0.6705745822976628
# Account_account_type 0.024368497568086005
# Channel 0.0051777412717597055
# Operating_System 0.05686423013890531
# Error_Code 0.008134807220897575
# Type_General_Automatic 0.002660438242567143
# IP_Address 0.6931323833786627
# MAC_Address 0.6914920628718921
# Access_Medium 0.028750017661472022
# Location 0.6860548874836779
# Recipient_Account_Number 0.6833687957979581
# Customer_flag_change_of_authentication_1 0.15825754757176014
# Customer_flag_change_of_authentication_2 0.3798576335900043
# Customer_flag_change_of_authentication_3 0.1508158942450238
# Customer_flag_change_of_authentication_4 0.3132868633447433
# Customer_rooting_jailbreak_indicator 0.025928572897128167
# Customer_mobile_roaming_indicator 0.011517370425953025
# Customer_VPN_Indicator 0.016121619861778402
# Customer_flag_terminal_malicious_behavior_1 0.04153918488198489
# Customer_flag_terminal_malicious_behavior_2 0.06931947194880882
# Customer_flag_terminal_malicious_behavior_3 0.17457511356122307
# Customer_flag_terminal_malicious_behavior_4 0.00465447584599668
# Customer_flag_terminal_malicious_behavior_5 0.008631503965748601
# Customer_flag_terminal_malicious_behavior_6 0.021926923700586538
# Customer_inquery_atm_limit 0.24472058035013838
# Customer_increase_atm_limit 0.25187033024058575
# Account_indicator_release_limit_excess 0.000469654382132781
# Account_indicator_Openbanking 0.0023429798077131306
# Account_release_suspention 0.08942653228565121
# Transaction_Failure_Status 0.008134807220897575
# Another_Person_Account 0.0
# Unused_terminal_status 0.028172567316710327
# First_time_iOS_by_vulnerable_user 9.044438201872429e-05
# Flag_deposit_more_than_tenMillion 0.09012000678182773
# Unused_account_status 0.0011378248636475204
# Recipient_account_suspend_status 0.13221814967306322
# ------------------
# a
# Customer_Gender 7.462521326806252e-05
# Customer_personal_identifier 0.33830742506358175
# Customer_identification_number 0.3440995530976909
# Customer_credit_rating 0.009284789724425209
# Customer_loan_type 0.019588433411926558
# Account_account_number 0.3441478540860474
# Account_account_type 0.0244103919753061
# Channel 0.00808301837027738
# Operating_System 0.01580533058136467
# Error_Code 0.002666291443189754
# Type_General_Automatic 0.0004755510098232376
# IP_Address 0.6931471805599454
# MAC_Address 0.3433223660324302
# Access_Medium 0.016667658279779066
# Location 0.3369842092199434
# Recipient_Account_Number 0.344946748654712
# Customer_flag_change_of_authentication_1 0.018209629671639388
# Customer_flag_change_of_authentication_2 0.11723966595384944
# Customer_flag_change_of_authentication_3 0.06727153985071063
# Customer_flag_change_of_authentication_4 0.23145496161785056
# Customer_rooting_jailbreak_indicator 0.02155237927769302
# Customer_mobile_roaming_indicator 0.027377231462739335
# Customer_VPN_Indicator 0.0613587715855308
# Customer_flag_terminal_malicious_behavior_1 0.0021113979342575035
# Customer_flag_terminal_malicious_behavior_2 0.09482735925332217
# Customer_flag_terminal_malicious_behavior_3 0.05159345367452378
# Customer_flag_terminal_malicious_behavior_4 5.44621686833864e-05
# Customer_flag_terminal_malicious_behavior_5 0.14571920582434197
# Customer_flag_terminal_malicious_behavior_6 0.0010895883518259998
# Customer_inquery_atm_limit 0.20714831416359616
# Customer_increase_atm_limit 0.021922371066171394
# Account_indicator_release_limit_excess 0.007525739963039713
# Account_indicator_Openbanking 0.006981977714981405
# Account_release_suspention 0.04147509718165616
# Transaction_Failure_Status 0.1358050117937648
# Another_Person_Account 0.0
# Unused_terminal_status 0.007517637664796144
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.023915590353115388
# Unused_account_status 0.039531928547047186
# Recipient_account_suspend_status 0.07004032295469245
# ------------------
# j
# Customer_Gender 0.0001620612711709492
# Customer_personal_identifier 0.3127616467263967
# Customer_identification_number 0.3432596861993402
# Customer_credit_rating 0.03602109930726402
# Customer_loan_type 0.009292939129061711
# Account_account_number 0.3437353631453238
# Account_account_type 0.024537833631419325
# Channel 0.02084174163240467
# Operating_System 0.0066924536432116264
# Error_Code 0.021258406929464593
# Type_General_Automatic 0.00013567754803954502
# IP_Address 0.6931471805599451
# MAC_Address 0.34334844702749967
# Access_Medium 0.0218560259113863
# Location 0.3435722953446426
# Recipient_Account_Number 0.3434318611075448
# Customer_flag_change_of_authentication_1 0.007425688104151493
# Customer_flag_change_of_authentication_2 0.0027803915248557245
# Customer_flag_change_of_authentication_3 0.2932310263787095
# Customer_flag_change_of_authentication_4 0.04953917611528267
# Customer_rooting_jailbreak_indicator 0.016093599848255414
# Customer_mobile_roaming_indicator 0.006981977714981405
# Customer_VPN_Indicator 0.021258406929464593
# Customer_flag_terminal_malicious_behavior_1 0.006981977714981405
# Customer_flag_terminal_malicious_behavior_2 0.026531170076640964
# Customer_flag_terminal_malicious_behavior_3 0.0067116184673546376
# Customer_flag_terminal_malicious_behavior_4 0.006251517238349549
# Customer_flag_terminal_malicious_behavior_5 0.018599363580493574
# Customer_flag_terminal_malicious_behavior_6 0.02377288302355405
# Customer_inquery_atm_limit 0.06806523628223213
# Customer_increase_atm_limit 0.007463020490320316
# Account_indicator_release_limit_excess 0.04581206863695143
# Account_indicator_Openbanking 0.002768222727604636
# Account_release_suspention 0.019984443584952317
# Transaction_Failure_Status 0.021258406929464593
# Another_Person_Account 0.0
# Unused_terminal_status 0.01706366944848698
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.016254945235078866
# Unused_account_status 0.0
# Recipient_account_suspend_status 0.0
# ------------------
# h
# Customer_Gender 0.005874810948147155
# Customer_personal_identifier 0.3434287364852917
# Customer_identification_number 0.3435876972905175
# Customer_credit_rating 0.023654543996567294
# Customer_loan_type 0.012395706048428847
# Account_account_number 0.34339748988934093
# Account_account_type 0.02916855017020654
# Channel 0.013529654282237876
# Operating_System 0.03688764607207642
# Error_Code 0.012717221951350017
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.34298204990050524
# Access_Medium 0.03719246178228903
# Location 0.3436518809667794
# Recipient_Account_Number 0.3438155430701279
# Customer_flag_change_of_authentication_1 0.14494272254344
# Customer_flag_change_of_authentication_2 0.06720795469880966
# Customer_flag_change_of_authentication_3 0.03583479591962781
# Customer_flag_change_of_authentication_4 0.09004201470830973
# Customer_rooting_jailbreak_indicator 0.018174607649912113
# Customer_mobile_roaming_indicator 0.08195097686907525
# Customer_VPN_Indicator 7.489200662684991e-05
# Customer_flag_terminal_malicious_behavior_1 0.0987144934166643
# Customer_flag_terminal_malicious_behavior_2 0.03044402264283932
# Customer_flag_terminal_malicious_behavior_3 0.09716841103721391
# Customer_flag_terminal_malicious_behavior_4 0.00872983781058511
# Customer_flag_terminal_malicious_behavior_5 0.00032063688944457264
# Customer_flag_terminal_malicious_behavior_6 0.01964017312747581
# Customer_inquery_atm_limit 0.15578270464016433
# Customer_increase_atm_limit 0.06290388369347051
# Account_indicator_release_limit_excess 0.054468574834470186
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.0017315878216810352
# Transaction_Failure_Status 0.0011912045366644036
# Another_Person_Account 0.0
# Unused_terminal_status 0.08868584766264336
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.03670626888832621
# Unused_account_status 0.04065980716065275
# Recipient_account_suspend_status 0.03067245612364104
# ------------------
# k
# Customer_Gender 5.126951920826499e-06
# Customer_personal_identifier 0.32689616283863115
# Customer_identification_number 0.3432294509156831
# Customer_credit_rating 0.012781319354231714
# Customer_loan_type 0.015538236090487798
# Account_account_number 0.34358337453838583
# Account_account_type 0.055839882473764015
# Channel 0.006395739205042691
# Operating_System 0.027338454682179384
# Error_Code 0.009885682615295337
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599452
# MAC_Address 0.34405856293960657
# Access_Medium 0.01167411139984357
# Location 0.344558579995495
# Recipient_Account_Number 0.34326207935686304
# Customer_flag_change_of_authentication_1 0.11442205834865041
# Customer_flag_change_of_authentication_2 0.014138888425467433
# Customer_flag_change_of_authentication_3 0.016644899286963517
# Customer_flag_change_of_authentication_4 0.0012182824214131223
# Customer_rooting_jailbreak_indicator 0.03597375665014844
# Customer_mobile_roaming_indicator 0.017649227464594814
# Customer_VPN_Indicator 0.03597375665014844
# Customer_flag_terminal_malicious_behavior_1 0.001970187979844333
# Customer_flag_terminal_malicious_behavior_2 0.02086931495473151
# Customer_flag_terminal_malicious_behavior_3 0.19054074840553842
# Customer_flag_terminal_malicious_behavior_4 0.0018372140584793984
# Customer_flag_terminal_malicious_behavior_5 0.040771896354041964
# Customer_flag_terminal_malicious_behavior_6 0.001541058619663154
# Customer_inquery_atm_limit 0.3240805547596516
# Customer_increase_atm_limit 3.1573482609114365e-05
# Account_indicator_release_limit_excess 0.01198884953269052
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.006640750570699314
# Transaction_Failure_Status 0.17522139372770712
# Another_Person_Account 0.0
# Unused_terminal_status 0.3618002012777616
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0018724593042486071
# Unused_account_status 0.0
# Recipient_account_suspend_status 0.10053739118486582
# ------------------
# c
# Customer_Gender 0.023375175097375543
# Customer_personal_identifier 0.3263670056585617
# Customer_identification_number 0.3380455428422228
# Customer_credit_rating 0.06659312540931295
# Customer_loan_type 0.020787344420089476
# Account_account_number 0.33810165223357297
# Account_account_type 0.0005238599453675644
# Channel 0.001921302016729156
# Operating_System 0.005534885245872127
# Error_Code 1.535288393799414e-05
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.3432016350977174
# Access_Medium 0.057164346433150895
# Location 0.34378848950213486
# Recipient_Account_Number 0.3431407933059912
# Customer_flag_change_of_authentication_1 0.017779947408796595
# Customer_flag_change_of_authentication_2 0.043505026864249584
# Customer_flag_change_of_authentication_3 0.09139149561872102
# Customer_flag_change_of_authentication_4 2.7901119515817696e-05
# Customer_rooting_jailbreak_indicator 2.8442742454607072e-06
# Customer_mobile_roaming_indicator 0.013246711574227662
# Customer_VPN_Indicator 0.006981977714981405
# Customer_flag_terminal_malicious_behavior_1 0.0002934660875557552
# Customer_flag_terminal_malicious_behavior_2 0.006954440563697547
# Customer_flag_terminal_malicious_behavior_3 0.012800116859349885
# Customer_flag_terminal_malicious_behavior_4 0.03186398083143651
# Customer_flag_terminal_malicious_behavior_5 0.03127426012940864
# Customer_flag_terminal_malicious_behavior_6 0.0028018965285218564
# Customer_inquery_atm_limit 0.13501531179769619
# Customer_increase_atm_limit 0.15003344302444363
# Account_indicator_release_limit_excess 0.09399799287529709
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.027925509692018863
# Transaction_Failure_Status 0.0031860189443361224
# Another_Person_Account 0.0
# Unused_terminal_status 0.19576580941148816
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.05510686658505943
# Unused_account_status 0.0683818512389091
# Recipient_account_suspend_status 0.009241499286931857
# ------------------
# g
# Customer_Gender 0.007350498197833663
# Customer_personal_identifier 0.3251525744427254
# Customer_identification_number 0.336909535226578
# Customer_credit_rating 0.009961628597534841
# Customer_loan_type 0.022017867875186604
# Account_account_number 0.3374152435010552
# Account_account_type 0.04395172219776523
# Channel 0.00358758401892131
# Operating_System 0.027870642923514318
# Error_Code 0.006981977714981405
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599452
# MAC_Address 0.343543223701872
# Access_Medium 0.014254659541916835
# Location 0.34334666221523963
# Recipient_Account_Number 0.34319531986934143
# Customer_flag_change_of_authentication_1 0.01929248270229095
# Customer_flag_change_of_authentication_2 0.08815884263677462
# Customer_flag_change_of_authentication_3 0.003312244409315032
# Customer_flag_change_of_authentication_4 0.03225222523462623
# Customer_rooting_jailbreak_indicator 0.031199422285371325
# Customer_mobile_roaming_indicator 0.03647338749083743
# Customer_VPN_Indicator 0.012434299656009992
# Customer_flag_terminal_malicious_behavior_1 0.0011664221877698301
# Customer_flag_terminal_malicious_behavior_2 0.09981248219567726
# Customer_flag_terminal_malicious_behavior_3 0.014894314514625931
# Customer_flag_terminal_malicious_behavior_4 0.0017304153704383145
# Customer_flag_terminal_malicious_behavior_5 0.014911848629830225
# Customer_flag_terminal_malicious_behavior_6 0.021745394377833065
# Customer_inquery_atm_limit 0.10141627960621839
# Customer_increase_atm_limit 0.04422463640980072
# Account_indicator_release_limit_excess 0.042171915781261754
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.0
# Transaction_Failure_Status 0.006981977714981405
# Another_Person_Account 0.0
# Unused_terminal_status 0.12793674790069984
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0
# Unused_account_status 0.1691495015098026
# Recipient_account_suspend_status 0.023163134164397945
# ------------------
# i
# Customer_Gender 0.020606146529678855
# Customer_personal_identifier 0.3203557923983686
# Customer_identification_number 0.3327561098621958
# Customer_credit_rating 0.009614420587218661
# Customer_loan_type 0.005677610894916103
# Account_account_number 0.3313195959906624
# Account_account_type 0.01149161500853973
# Channel 0.010231841716177945
# Operating_System 0.027187433144019807
# Error_Code 0.0
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.34318005580898564
# Access_Medium 0.016079850930699163
# Location 0.34321421004178954
# Recipient_Account_Number 0.34286344005537917
# Customer_flag_change_of_authentication_1 0.028559461849879304
# Customer_flag_change_of_authentication_2 0.006701093134139202
# Customer_flag_change_of_authentication_3 0.00012240426697616297
# Customer_flag_change_of_authentication_4 0.006981977714981405
# Customer_rooting_jailbreak_indicator 0.02324414063881114
# Customer_mobile_roaming_indicator 0.010511425321212927
# Customer_VPN_Indicator 0.04489044958742281
# Customer_flag_terminal_malicious_behavior_1 0.003988490840890626
# Customer_flag_terminal_malicious_behavior_2 0.002471836138445358
# Customer_flag_terminal_malicious_behavior_3 0.01047562558784863
# Customer_flag_terminal_malicious_behavior_4 0.07713535998600447
# Customer_flag_terminal_malicious_behavior_5 0.043125471617567725
# Customer_flag_terminal_malicious_behavior_6 0.001930535408478498
# Customer_inquery_atm_limit 0.014067039412645505
# Customer_increase_atm_limit 0.017321839779612613
# Account_indicator_release_limit_excess 0.06280504846182719
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.0008168734352280439
# Transaction_Failure_Status 0.0
# Another_Person_Account 0.0
# Unused_terminal_status 0.09042582762234709
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.02577247459727273
# Unused_account_status 0.009908680585930127
# Recipient_account_suspend_status 0.003951217104725104
# ------------------
# b
# Customer_Gender 0.003413051271117098
# Customer_personal_identifier 0.33901870707954035
# Customer_identification_number 0.33713192517961793
# Customer_credit_rating 0.0023811423585601925
# Customer_loan_type 0.025342314290039587
# Account_account_number 0.33748873327067047
# Account_account_type 0.023763123179454598
# Channel 0.005863144834952155
# Operating_System 0.006452553534799904
# Error_Code 0.00040882201514183016
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.34326140522157667
# Access_Medium 0.017092852270353058
# Location 0.34319962863132897
# Recipient_Account_Number 0.3370091691011246
# Customer_flag_change_of_authentication_1 0.00019390358102484677
# Customer_flag_change_of_authentication_2 0.057273116877445386
# Customer_flag_change_of_authentication_3 0.04595411302577495
# Customer_flag_change_of_authentication_4 0.03488082212927199
# Customer_rooting_jailbreak_indicator 0.07386889506620105
# Customer_mobile_roaming_indicator 0.03028919144280206
# Customer_VPN_Indicator 0.013441180335509846
# Customer_flag_terminal_malicious_behavior_1 0.028278278812253723
# Customer_flag_terminal_malicious_behavior_2 0.03793906217741516
# Customer_flag_terminal_malicious_behavior_3 0.003586577739147844
# Customer_flag_terminal_malicious_behavior_4 0.007706431138133986
# Customer_flag_terminal_malicious_behavior_5 0.016106187059264164
# Customer_flag_terminal_malicious_behavior_6 0.00785521051600284
# Customer_inquery_atm_limit 0.0033681410136941372
# Customer_increase_atm_limit 0.11825542520240255
# Account_indicator_release_limit_excess 0.0437630742228771
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.1051284354735734
# Transaction_Failure_Status 0.037327719877207385
# Another_Person_Account 0.0
# Unused_terminal_status 0.1366876521243655
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.009048878494847378
# Unused_account_status 0.023730842529953465
# Recipient_account_suspend_status 0.021970656149278952
# ------------------
# f
# Customer_Gender 0.02031128636210015
# Customer_personal_identifier 0.3434373436682451
# Customer_identification_number 0.34344271321030023
# Customer_credit_rating 0.040734863695008595
# Customer_loan_type 0.017600909216435527
# Account_account_number 0.34336012647231984
# Account_account_type 0.03626226763549284
# Channel 0.0
# Operating_System 0.013192600279545004
# Error_Code 0.010511425321212927
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.34308412397157223
# Access_Medium 0.020298682117632742
# Location 0.3436651122682115
# Recipient_Account_Number 0.3434695614438065
# Customer_flag_change_of_authentication_1 0.1193772111241182
# Customer_flag_change_of_authentication_2 0.1453186273847919
# Customer_flag_change_of_authentication_3 0.006544158157750709
# Customer_flag_change_of_authentication_4 0.015188103500248486
# Customer_rooting_jailbreak_indicator 0.0
# Customer_mobile_roaming_indicator 0.0
# Customer_VPN_Indicator 0.0
# Customer_flag_terminal_malicious_behavior_1 0.0
# Customer_flag_terminal_malicious_behavior_2 0.0
# Customer_flag_terminal_malicious_behavior_3 0.0
# Customer_flag_terminal_malicious_behavior_4 0.0
# Customer_flag_terminal_malicious_behavior_5 0.0
# Customer_flag_terminal_malicious_behavior_6 0.0
# Customer_inquery_atm_limit 0.055043867628572454
# Customer_increase_atm_limit 0.1391753576589606
# Account_indicator_release_limit_excess 0.034934524935146094
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.006981977714981405
# Transaction_Failure_Status 0.010511425321212927
# Another_Person_Account 0.0
# Unused_terminal_status 0.003478298769743019
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0
# Unused_account_status 0.0906297931113163
# Recipient_account_suspend_status 0.002206819988613388
# ------------------
# d
# Customer_Gender 0.014173487482175152
# Customer_personal_identifier 0.34404215884025074
# Customer_identification_number 0.34419244409194805
# Customer_credit_rating 0.013723301243530531
# Customer_loan_type 0.010797162981124004
# Account_account_number 0.3439227161892175
# Account_account_type 0.015233015186546494
# Channel 0.00549595435578258
# Operating_System 0.007749385577532262
# Error_Code 0.0
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599451
# MAC_Address 0.34290625827862536
# Access_Medium 0.017285201785716176
# Location 0.3368513276047151
# Recipient_Account_Number 0.34376622513696914
# Customer_flag_change_of_authentication_1 0.060858011924152876
# Customer_flag_change_of_authentication_2 0.10628448312241238
# Customer_flag_change_of_authentication_3 0.08627881255807177
# Customer_flag_change_of_authentication_4 0.10186230310448326
# Customer_rooting_jailbreak_indicator 0.03360325389022772
# Customer_mobile_roaming_indicator 0.12668845935193457
# Customer_VPN_Indicator 1.2136677655445911e-05
# Customer_flag_terminal_malicious_behavior_1 5.264384379396222e-05
# Customer_flag_terminal_malicious_behavior_2 0.07422043835027765
# Customer_flag_terminal_malicious_behavior_3 0.0006629817236549233
# Customer_flag_terminal_malicious_behavior_4 0.0007707003181881451
# Customer_flag_terminal_malicious_behavior_5 0.017562168559032136
# Customer_flag_terminal_malicious_behavior_6 0.055929285517073
# Customer_inquery_atm_limit 0.06020561317383118
# Customer_increase_atm_limit 0.03208784892623773
# Account_indicator_release_limit_excess 0.07054419319338304
# Account_indicator_Openbanking 0.003478298769743019
# Account_release_suspention 0.0020293989117267483
# Transaction_Failure_Status 0.0
# Another_Person_Account 0.0
# Unused_terminal_status 0.0
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.021731523399405664
# Unused_account_status 0.000724658322216973
# Recipient_account_suspend_status 0.025057198496886684
# ------------------
# e
# Customer_Gender 0.0009464352223948671
# Customer_personal_identifier 0.33282494747251967
# Customer_identification_number 0.34362253600011583
# Customer_credit_rating 0.019334000011331866
# Customer_loan_type 0.013450929960322712
# Account_account_number 0.3442925143585555
# Account_account_type 0.12521856201862439
# Channel 0.0
# Operating_System 0.00949756971464644
# Error_Code 0.0006341813954174673
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.3442884436464851
# Access_Medium 0.01354932981980954
# Location 0.3432971395464765
# Recipient_Account_Number 0.34386441759300473
# Customer_flag_change_of_authentication_1 0.15847187489526682
# Customer_flag_change_of_authentication_2 0.27491750404524995
# Customer_flag_change_of_authentication_3 6.354491019234794e-07
# Customer_flag_change_of_authentication_4 0.04233125850606847
# Customer_rooting_jailbreak_indicator 2.2173358870587764e-07
# Customer_mobile_roaming_indicator 0.0
# Customer_VPN_Indicator 0.0
# Customer_flag_terminal_malicious_behavior_1 0.0
# Customer_flag_terminal_malicious_behavior_2 0.02400299922616129
# Customer_flag_terminal_malicious_behavior_3 0.0
# Customer_flag_terminal_malicious_behavior_4 0.0
# Customer_flag_terminal_malicious_behavior_5 0.0
# Customer_flag_terminal_malicious_behavior_6 0.00020729966145286574
# Customer_inquery_atm_limit 0.02903417805969757
# Customer_increase_atm_limit 0.12476271648016428
# Account_indicator_release_limit_excess 0.00015468143522361135
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.017649227464594814
# Transaction_Failure_Status 0.00320547059948785
# Another_Person_Account 0.0
# Unused_terminal_status 0.017649227464594814
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.0
# Unused_account_status 0.10368205301970075
# Recipient_account_suspend_status 0.004718416021693532
# ------------------
# l
# Customer_Gender 0.04220478766308674
# Customer_personal_identifier 0.32054552432703765
# Customer_identification_number 0.33254017064017616
# Customer_credit_rating 0.032490009292354766
# Customer_loan_type 0.008226882710373253
# Account_account_number 0.33142424976192036
# Account_account_type 0.040734168327449596
# Channel 0.008328167851354002
# Operating_System 0.025763970011906983
# Error_Code 0.006981977714981405
# Type_General_Automatic 0.0
# IP_Address 0.6931471805599454
# MAC_Address 0.34362834646598567
# Access_Medium 0.06207764627567444
# Location 0.3431470640549205
# Recipient_Account_Number 0.3433015708698877
# Customer_flag_change_of_authentication_1 0.03225222523462623
# Customer_flag_change_of_authentication_2 0.010511425321212927
# Customer_flag_change_of_authentication_3 0.08495058592890851
# Customer_flag_change_of_authentication_4 0.13149795723903016
# Customer_rooting_jailbreak_indicator 0.01659505895171357
# Customer_mobile_roaming_indicator 0.00036558196756571746
# Customer_VPN_Indicator 0.017649227464594814
# Customer_flag_terminal_malicious_behavior_1 0.010511425321212927
# Customer_flag_terminal_malicious_behavior_2 0.0008255027881577634
# Customer_flag_terminal_malicious_behavior_3 0.15181919943479336
# Customer_flag_terminal_malicious_behavior_4 0.008633321478110498
# Customer_flag_terminal_malicious_behavior_5 0.036335858788806824
# Customer_flag_terminal_malicious_behavior_6 0.0015759107085707817
# Customer_inquery_atm_limit 0.19373433759505584
# Customer_increase_atm_limit 0.07906248824049147
# Account_indicator_release_limit_excess 0.05344135448064958
# Account_indicator_Openbanking 0.0
# Account_release_suspention 0.1281650719220171
# Transaction_Failure_Status 0.006981977714981405
# Another_Person_Account 0.0
# Unused_terminal_status 0.03597375665014844
# First_time_iOS_by_vulnerable_user 0.0
# Flag_deposit_more_than_tenMillion 0.10977815175546907
# Unused_account_status 0.019419462092509134
# Recipient_account_suspend_status 0.022259716144957538
# ------------------

# %%
statis
# Out:
#    Fraud_Type  Data_Quality  Data_Diagnostic  Conti_statis  Cate_statis
# 0           m      0.000000         0.000000      0.155604     0.175126
# 1           a      0.640295         0.992049      0.152708     0.103506
# 2           j      0.687274         0.989172      0.127750     0.086558
# 3           h      0.664995         0.996475      0.134996     0.099792
# 4           k      0.621138         0.990007      0.182498     0.106278
# 5           c      0.674333         1.000000      0.123155     0.095105
# 6           g      0.656299         0.997421      0.160107     0.091575
# 7           i      0.707600         0.994577      0.155788     0.080400
# 8           b      0.669836         0.999868      0.124188     0.089552
# 9           f      0.701238         0.999795      0.168780     0.086388
# 10          d      0.674163         0.999092      0.141188     0.090584
# 11          e      0.687229         0.999954      0.189443     0.090945
# 12          l      0.664792         0.999176      0.135903     0.099680

# %% [markdown]
# # Model selection

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.naive_bayes import GaussianNB
from catboost import CatBoostClassifier
import pickle

# 모델 초기화 함수
def get_new_models():
    return {
        'Random_Forest': RandomForestClassifier(n_estimators=100, random_state=42),
        'Logistic_Regression': LogisticRegression(multi_class='ovr', solver='lbfgs', max_iter=1000),
        'Naive_Bayes': GaussianNB(),
        'CatBoost': CatBoostClassifier(iterations=1000, depth=6, learning_rate=0.1, loss_function='MultiClass', random_seed=42),
        'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', objective='multi:softprob')
    }


# SRA 계산 함수 정의
def calculate_sra(X_real_in, y_real, X_syn_in, y_syn):
    # 데이터 분할

    real_scores = {}
    synth_scores = {}
    model_instances = {}

    # 각 모델에 대해 AUROC 점수 계산
    for model_name, model_real in get_new_models().items():
        print("Model: ", model_name)
        X_train_real, X_test_real, y_train_real, y_test_real = train_test_split(X_real_in, y_real, test_size=0.2, random_state=42, stratify=y_real)

        model_real.fit(X_train_real, y_train_real)
        y_pred_real = model_real.predict_proba(X_test_real)
        real_scores[model_name] = roc_auc_score(y_test_real, y_pred_real, multi_class='ovr')
        print('Real: ', real_scores)
        # save
        model_save_name = '4_1_copulagan_model_real_' + model_name +'.pkl'
        pickle.dump(model_real, open(model_save_name, "wb"))

        # 합성 데이터에서 모델 학습 및 성능 평가
        X_train_synth, X_test_synth, y_train_synth, y_test_synth = train_test_split(X_syn_in, y_syn, test_size=0.2, random_state=42, stratify=y_syn)

        model_syn = get_new_models()[model_name]  # 모델을 새로 초기화
        model_syn.fit(X_train_synth, y_train_synth)
        y_pred_synth = model_syn.predict_proba(X_test_real)
        synth_scores[model_name] = roc_auc_score(y_test_real, y_pred_synth, multi_class='ovr')
        print('Syn: ', synth_scores)
        # save
        model_save_name = '4_1_copulagan_model_syn_' + model_name +'.pkl'
        pickle.dump(model_real, open(model_save_name, "wb"))

        # 모델 인스턴스 저장
        model_instances[model_name] = {'real_model': model_real, 'syn_model': model_syn}

    # 순위 계산
    real_ranking = sorted(real_scores, key=real_scores.get, reverse=True)
    synth_ranking = sorted(synth_scores, key=synth_scores.get, reverse=True)

    return real_scores, synth_scores, real_ranking, synth_ranking, model_instances


# SRA 값 계산
#fraud_type = 'a'

df_real = saved_train.copy()
df_syn = all_synthetic_data.copy()
df_real = df_real.drop('Time_difference_seconds', axis=1)

df_real_m = df_real[df_real.Fraud_Type == 'm'].sample(n=100, random_state=42)
df_real_not_m = df_real[df_real.Fraud_Type != 'm']
df_real_100 = pd.concat([df_real_m, df_real_not_m])

df_syn_m = df_syn[df_syn.Fraud_Type == 'm'].sample(n=100, random_state=42)
df_syn_not_m = df_syn[df_syn.Fraud_Type != 'm']
df_syn_100 = pd.concat([df_syn_m, df_syn_not_m])
df_syn_100.dropna(inplace=True)

###################
X_real = df_real_100.drop(columns=['Fraud_Type'])
y_real = df_real_100['Fraud_Type']

X_syn = df_syn_100.drop(columns=['Fraud_Type'])
y_syn = df_syn_100['Fraud_Type']


# 레이블 정리
le_subclass = LabelEncoder()
train_y_encoded = le_subclass.fit_transform(saved_train.Fraud_Type)
for i, label in enumerate(le_subclass.classes_):
    print(f"원래 레이블: {label}, 변환된 숫자: {i}")

y_real = le_subclass.transform(y_real)
y_syn = le_subclass.transform(y_syn)

# time_difference를 초로 바꾸기
X_real['Time_difference_seconds'] = pd.to_timedelta(X_real['Time_difference']).dt.total_seconds()
X_syn['Time_difference_seconds'] = pd.to_timedelta(X_syn['Time_difference']).dt.total_seconds()

# unique한 코드 지우기
X_real.drop('Customer_personal_identifier', axis=1, inplace=True)
X_syn.drop('Customer_personal_identifier', axis=1, inplace=True)

# 범주형 변수 인코딩
categorical_columns = X_real.select_dtypes(include=['object', 'category']).columns

# 훈련 데이터 인코딩
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X_real[categorical_columns] = ordinal_encoder.fit_transform(X_real[categorical_columns])
X_syn[categorical_columns] = ordinal_encoder.transform(X_syn[categorical_columns])

# 특성 순서 저장
feature_order = X_real.columns.tolist()
####################

real_scores, synth_scores, real_ranking, synth_ranking, models_out = calculate_sra(X_real[feature_order], y_real, X_syn[feature_order], y_syn)
# Out:
# 원래 레이블: a, 변환된 숫자: 0
# 원래 레이블: b, 변환된 숫자: 1
# 원래 레이블: c, 변환된 숫자: 2
# 원래 레이블: d, 변환된 숫자: 3
# 원래 레이블: e, 변환된 숫자: 4
# 원래 레이블: f, 변환된 숫자: 5
# 원래 레이블: g, 변환된 숫자: 6
# 원래 레이블: h, 변환된 숫자: 7
# 원래 레이블: i, 변환된 숫자: 8
# 원래 레이블: j, 변환된 숫자: 9
# 원래 레이블: k, 변환된 숫자: 10
# 원래 레이블: l, 변환된 숫자: 11
# 원래 레이블: m, 변환된 숫자: 12
# Model:  Random_Forest
# Real:  {'Random_Forest': 0.9431650641025642}
# Syn:  {'Random_Forest': 0.7679887820512821}
# Model:  Logistic_Regression
# Real:  {'Random_Forest': 0.9431650641025642, 'Logistic_Regression': 0.7774358974358975}
# Syn:  {'Random_Forest': 0.7679887820512821, 'Logistic_Regression': 0.6963141025641024}
# Model:  Naive_Bayes
# Real:  {'Random_Forest': 0.9431650641025642, 'Logistic_Regression': 0.7774358974358975, 'Naive_Bayes': 0.7818910256410256}
# Syn:  {'Random_Forest': 0.7679887820512821, 'Logistic_Regression': 0.6963141025641024, 'Naive_Bayes': 0.7265785256410257}
# Model:  CatBoost
# 0:	learn: 2.4658552	total: 65.8ms	remaining: 1m 5s
# 1:	learn: 2.4138873	total: 129ms	remaining: 1m 4s
# 2:	learn: 2.3305589	total: 194ms	remaining: 1m 4s
# 3:	learn: 2.2611016	total: 258ms	remaining: 1m 4s
# 4:	learn: 2.2011874	total: 322ms	remaining: 1m 4s
# 5:	learn: 2.1539700	total: 384ms	remaining: 1m 3s
# 6:	learn: 2.1138173	total: 448ms	remaining: 1m 3s
# 7:	learn: 2.0518443	total: 513ms	remaining: 1m 3s
# 8:	learn: 1.9979911	total: 574ms	remaining: 1m 3s
# 9:	learn: 1.9616276	total: 639ms	remaining: 1m 3s
# 10:	learn: 1.9151573	total: 704ms	remaining: 1m 3s
# 11:	learn: 1.8746147	total: 765ms	remaining: 1m 3s
# 12:	learn: 1.8437380	total: 833ms	remaining: 1m 3s
# 13:	learn: 1.7798808	total: 896ms	remaining: 1m 3s
# 14:	learn: 1.7374816	total: 975ms	remaining: 1m 4s
# 15:	learn: 1.7117990	total: 1.03s	remaining: 1m 3s
# 16:	learn: 1.6809291	total: 1.1s	remaining: 1m 3s
# 17:	learn: 1.6472643	total: 1.16s	remaining: 1m 3s
# 18:	learn: 1.6221640	total: 1.23s	remaining: 1m 3s
# 19:	learn: 1.5907247	total: 1.29s	remaining: 1m 3s
# 20:	learn: 1.5655787	total: 1.35s	remaining: 1m 3s
# 21:	learn: 1.5456791	total: 1.41s	remaining: 1m 2s
# 22:	learn: 1.5194258	total: 1.48s	remaining: 1m 2s
# 23:	learn: 1.4997154	total: 1.55s	remaining: 1m 3s
# 24:	learn: 1.4833250	total: 1.62s	remaining: 1m 3s
# 987:	learn: 0.0003801	total: 12m 46s	remaining: 9.31s
# 988:	learn: 0.0003795	total: 12m 48s	remaining: 8.54s
# 989:	learn: 0.0003791	total: 12m 49s	remaining: 7.77s
# 990:	learn: 0.0003789	total: 12m 50s	remaining: 7s
# 991:	learn: 0.0003783	total: 12m 51s	remaining: 6.22s
# 992:	learn: 0.0003782	total: 12m 52s	remaining: 5.44s
# 993:	learn: 0.0003781	total: 12m 53s	remaining: 4.67s
# 994:	learn: 0.0003776	total: 12m 53s	remaining: 3.89s
# 995:	learn: 0.0003770	total: 12m 54s	remaining: 3.11s
# 996:	learn: 0.0003766	total: 12m 54s	remaining: 2.33s
# 997:	learn: 0.0003762	total: 12m 55s	remaining: 1.55s
# 998:	learn: 0.0003759	total: 12m 56s	remaining: 777ms
# 999:	learn: 0.0003758	total: 12m 56s	remaining: 0us
# Syn:  {'Random_Forest': 0.7679887820512821, 'Logistic_Regression': 0.6963141025641024, 'Naive_Bayes': 0.7265785256410257, 'CatBoost': 0.768573717948718}
# Model:  XGBoost
# Real:  {'Random_Forest': 0.9431650641025642, 'Logistic_Regression': 0.7774358974358975, 'Naive_Bayes': 0.7818910256410256, 'CatBoost': 0.9669070512820513, 'XGBoost': 0.9657532051282052}
# Syn:  {'Random_Forest': 0.7679887820512821, 'Logistic_Regression': 0.6963141025641024, 'Naive_Bayes': 0.7265785256410257, 'CatBoost': 0.768573717948718, 'XGBoost': 0.7495352564102564}

# %%
real_scores
# Out:
# {'Random_Forest': 0.9431650641025642,
#  'Logistic_Regression': 0.7774358974358975,
#  'Naive_Bayes': 0.7818910256410256,
#  'CatBoost': 0.9669070512820513,
#  'XGBoost': 0.9657532051282052}

# %%
synth_scores
# Out:
# {'Random_Forest': 0.7679887820512821,
#  'Logistic_Regression': 0.6963141025641024,
#  'Naive_Bayes': 0.7265785256410257,
#  'CatBoost': 0.768573717948718,
#  'XGBoost': 0.7495352564102564}

# %%
real_ranking
# Out:
# ['CatBoost', 'XGBoost', 'Random_Forest', 'Naive_Bayes', 'Logistic_Regression']

# %%
synth_ranking
# Out:
# ['CatBoost', 'Random_Forest', 'XGBoost', 'Naive_Bayes', 'Logistic_Regression']

# %%
from scipy.stats import spearmanr

# 성능 지표를 데이터프레임으로 변환
real_df = pd.DataFrame(list(real_scores.items()), columns=['Model', 'Real_Score'])
synth_df = pd.DataFrame(list(synth_scores.items()), columns=['Model', 'Synth_Score'])

# 성능 지표 순위화
real_df['Real_Rank'] = real_df['Real_Score'].rank(ascending=False)
synth_df['Synth_Rank'] = synth_df['Synth_Score'].rank(ascending=False)

# 데이터프레임 병합 (모델 이름을 기준으로)
merged_df = pd.merge(real_df, synth_df, on='Model')

# 스피어만 순위 상관관계 계산
spearman_corr, _ = spearmanr(merged_df['Real_Rank'], merged_df['Synth_Rank'])

# 결과 출력
print(f"Spearman Rank Correlation: {spearman_corr:.4f}")
# Out:
# Spearman Rank Correlation: 0.9000

# %% [markdown]
# # Classification Performance

# %%
# 성능 차이 계산
score_differences = {model: real_scores[model] - synth_scores[model] for model in real_scores}

add = 0
# 결과 출력
for model, difference in score_differences.items():
    add += abs(difference)
    print(f"{model} difference: {difference:.6f}")
print()
print("평균: ", round(add / 5, 5))
# Out:
# Random_Forest difference: 0.175176
# Logistic_Regression difference: 0.081122
# Naive_Bayes difference: 0.055312
# CatBoost difference: 0.198333
# XGBoost difference: 0.216218
#
# 평균:  0.14523

# %% [markdown]
# # Feature extraction

# %%
import xgboost as xgb
import pandas as pd
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

# 실제 데이터셋으로 XGBoost 모델 학습
model_real = models_out['XGBoost']['real_model']

# 합성 데이터셋으로 XGBoost 모델 학습
model_synthetic = models_out['XGBoost']['syn_model']

# 실제 데이터셋에서의 피처 중요도
importance_real = model_real.get_booster().get_score(importance_type='weight')
importance_real_df = pd.DataFrame(list(importance_real.items()), columns=['Feature', 'Importance_Real'])

# 합성 데이터셋에서의 피처 중요도
importance_synthetic = model_synthetic.get_booster().get_score(importance_type='weight')
importance_synthetic_df = pd.DataFrame(list(importance_synthetic.items()), columns=['Feature', 'Importance_Synthetic'])

# 피처 중요도를 순위화
importance_real_df['Rank_Real'] = importance_real_df['Importance_Real'].rank(ascending=False)
importance_synthetic_df['Rank_Synthetic'] = importance_synthetic_df['Importance_Synthetic'].rank(ascending=False)

# 두 데이터프레임 병합 (모든 피처가 동일해야 함)
merged_df = pd.merge(importance_real_df, importance_synthetic_df, on='Feature', how='inner')

# 스피어만 순위 상관관계 계산
spearman_corr, _ = spearmanr(merged_df['Rank_Real'], merged_df['Rank_Synthetic'])
print(f"Spearman Rank Correlation: {spearman_corr:.4f}")

# 피처 중요도 비교 시각화
plt.figure(figsize=(10, 8))
plt.scatter(merged_df['Rank_Real'], merged_df['Rank_Synthetic'])
plt.title('Feature Importance Rank Comparison')
plt.xlabel('Rank in Real Data')
plt.ylabel('Rank in Synthetic Data')
plt.grid(True)
plt.show()
# Out:
# Spearman Rank Correlation: 0.4154

# %% [markdown]
# # 익명성 평가

# %%
import numpy as np
import pandas as pd

# 실제 데이터 (Original Data)와 합성 데이터 (Synthetic Data)를 불러옵니다.
df_real = subset  # 원본 데이터
df_synth = syn_subset  # 합성 데이터

# 평가에 사용할 칼럼들
key_columns = ['Customer_Birthyear', 'Customer_Gender', 'Customer_credit_rating', 'Customer_identification_number', 'Location','IP_Address','MAC_Address', 'Customer_personal_identifier',
               'Transaction_Datetime', 'Account_account_number']
target_column = 'Fraud_Type'

# TCAP 계산 함수 정의
def calculate_tcap(df_real, df_synth, key_columns, target_column):
    n = len(df_real)
    numerator = 0
    denominator = 0

    for i in range(n):
        real_key = tuple(df_real[key_columns].iloc[i].values)
        synth_key = tuple(df_synth[key_columns].iloc[i].values)

        if real_key == synth_key:
            denominator += 1
            if df_real[target_column].iloc[i] == df_synth[target_column].iloc[i]:
                numerator += 1

    tcap_value = numerator / denominator if denominator != 0 else 0
    return tcap_value

# TCAP 계산
tcap_value = calculate_tcap(df_real, df_synth, key_columns, target_column)
print(f"TCAP Value: {tcap_value:.4f}")
# Out:
# TCAP Value: 0.0000
